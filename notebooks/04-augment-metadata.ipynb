# %% [markdown]
# # Extract Product Metadata

# %%
# CATEGORY = "Baby_Products"
CATEGORY = "Video_Games"

# Define sequence lengths
MIN_SEQUENCE_LENGTH = 3
MAX_SEQUENCE_LENGTH = 100  # Adjust as needed

# %%
import sys
from pathlib import Path

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = NOTEBOOK_DIR.parent
sys.path.append(str(PROJECT_ROOT))

# Data directory
DATA_DIR = Path(PROJECT_ROOT, "data")
DATA_DIR.mkdir(exist_ok=True)

# %%
import json
import logging
import os
import threading
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

import polars as pl
from dotenv import load_dotenv
from google import genai
from IPython.display import display
from tqdm.notebook import tqdm

from src.logger import setup_logger

# Set environment variables to reduce Google API verbosity
os.environ["GRPC_VERBOSITY"] = "ERROR"
os.environ["GLOG_minloglevel"] = "2"

logger = setup_logger("clean-items")
logging.getLogger("httpcore").setLevel(logging.WARNING)
logging.getLogger("httpx").setLevel(logging.WARNING)
logging.getLogger("google_genai").setLevel(logging.WARNING)

# %%
load_dotenv()
# Out:
# True

# %%
# API settings
MODEL = "gemini-2.5-flash-lite"
# MODEL = "gemini-2.5-flash"
BATCH_SIZE: int = 10  # Items per API call (can process more titles at once)
MAX_RETRIES: int = 5
RETRY_DELAY: float = 1.0  # Seconds
RATE_LIMIT_DELAY: float = 0.1  # Seconds between API calls (faster for shorter text)
MAX_THREADS: int = 15  # Can use more threads for shorter text

# Text processing settings for titles
MAX_TITLE_LENGTH: int = 200  # Truncate titles before sending to API
MIN_TITLE_LENGTH: int = 10  # Minimum length to consider valid

# %% [markdown]
# ## 2. Load Data and Analyze Titles

# %%
# LOAD ORIGINAL METADATA
metadata_output_path = DATA_DIR / "output" / f"{CATEGORY}_items.parquet"
item_df = pl.read_parquet(metadata_output_path)
logger.info(f"Loaded {len(item_df):,} items from {metadata_output_path}")

# LOAD CLEANED DESCRIPTIONS
cleaned_descriptions_path = DATA_DIR / "output" / f"{CATEGORY}_descriptions_clean.csv"
cleaned_descriptions_df = pl.read_csv(cleaned_descriptions_path)
cleaned_descriptions_df = cleaned_descriptions_df.unique(subset=["parent_asin"])
cleaned_descriptions_df = cleaned_descriptions_df.filter(pl.col("clean_description") != "NA")
logger.info(f"Loaded {len(cleaned_descriptions_df):,} cleaned descriptions from {cleaned_descriptions_path}")

# LOAD CLEANED TITLES
cleaned_titles_path = DATA_DIR / "output" / f"{CATEGORY}_titles_clean.csv"
cleaned_titles_df = pl.read_csv(cleaned_titles_path)
cleaned_titles_df = cleaned_titles_df.unique(subset=["parent_asin"])
cleaned_titles_df = cleaned_titles_df.filter(pl.col("clean_title") != "NA")
logger.info(f"Loaded {len(cleaned_titles_df):,} cleaned titles from {cleaned_titles_path}")

# MERGE DATAFRAMES
item_df = item_df.join(cleaned_descriptions_df, on="parent_asin", how="inner")
item_df = item_df.join(cleaned_titles_df, on="parent_asin", how="inner")
logger.info(f"Merged {len(item_df):,} items with cleaned descriptions and titles")
# Out:
# 10:06:31 - Loaded 66,133 items from /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_items.parquet
# 10:06:31 - Loaded 66,121 cleaned descriptions from /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_descriptions_clean.csv
# 10:06:31 - Loaded 66,130 cleaned titles from /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_titles_clean.csv
# 10:06:31 - Merged 66,118 items with cleaned descriptions and titles

# %%
# Clean up xml tags that remain
item_df = item_df.with_columns(
    pl.col("clean_description")
    .str.replace_all(r"</?[^>]+>", " ")  # Remove all tags
    .str.replace_all(r"\s+", " ")  # Collapse multiple spaces
    .str.strip_chars()  # Trim whitespace
    .alias("clean_description"),
    pl.col("clean_title")
    .str.replace_all(r"</?[^>]+>", " ")  # Remove all tags
    .str.replace_all(r"\s+", " ")  # Collapse multiple spaces
    .str.strip_chars()  # Trim whitespace
    .alias("clean_title"),
)

assert (
    len(
        item_df.filter(pl.col("clean_description").str.contains("clean_description")).select(
            ["description_text", "clean_description"]
        )
    )
    == 0
)
assert len(item_df.filter(pl.col("clean_title").str.contains("clean_title")).select(["title", "clean_title"])) == 0

# %%
item_df = item_df.rename(
    {
        "description_text": "original_description",
        "clean_description": "description_text",
        "title": "original_title",
        "clean_title": "title",
    }
)
item_df.head()
# Out:
# shape: (5, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────┬───────────┬───────────┬───────────┐
# │ parent_asi ┆ original_t ┆ original_d ┆ features_ ┆ … ┆ price ┆ item_cont ┆ descripti ┆ title     │
# │ n          ┆ itle       ┆ escription ┆ text      ┆   ┆ ---   ┆ ext       ┆ on_text   ┆ ---       │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ str   ┆ ---       ┆ ---       ┆ str       │
# │ str        ┆ str        ┆ str        ┆ str       ┆   ┆       ┆ str       ┆ str       ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════╪═══════════╪═══════════╪═══════════╡
# │ B00CX6FZCC ┆ DeadPool   ┆ There are  ┆           ┆ … ┆       ┆ Product:  ┆ Step into ┆ Deadpool  │
# │            ┆ [Online    ┆ a few      ┆           ┆   ┆       ┆ DeadPool  ┆ the role  ┆ Digital   │
# │            ┆ Game Code] ┆ important  ┆           ┆   ┆       ┆ [Online   ┆ of a      ┆ Game Code │
# │            ┆            ┆ thin…      ┆           ┆   ┆       ┆ Game…     ┆ mercen…   ┆           │
# │ B07XM5HSGK ┆ HUYUN USB  ┆ Replacemen ┆ 100% New  ┆ … ┆ 9.99  ┆ Product:  ┆ This is a ┆ Razer Dea │
# │            ┆ Mouse      ┆ t for      ┆ High      ┆   ┆       ┆ HUYUN USB ┆ replaceme ┆ thAdder   │
# │            ┆ Cable Wire ┆ Razer      ┆ quality   ┆   ┆       ┆ Mouse     ┆ nt mouse  ┆ 3.5G 2013 │
# │            ┆ & F…       ┆ DeathAdd…  ┆ USB mous… ┆   ┆       ┆ Cable…    ┆ ca…       ┆ Chr…      │
# │ B001EDF55W ┆ RS3 -      ┆ Buckle up  ┆ Featuring ┆ … ┆ 7.42  ┆ Product:  ┆ Experienc ┆ RS3       │
# │            ┆ Racing     ┆ and strap  ┆ 6 breatht ┆   ┆       ┆ RS3 -     ┆ e the     ┆ Racing    │
# │            ┆ Simulation ┆ yourself   ┆ aking     ┆   ┆       ┆ Racing    ┆ most puls ┆ Simulatio │
# │            ┆ Three      ┆ i…         ┆ racin…    ┆   ┆       ┆ Simulati… ┆ e-poun…   ┆ n Three   │
# │ B004H0LQO8 ┆ Fishdom 5  ┆ We have    ┆ Build     ┆ … ┆       ┆ Product:  ┆ This coll ┆ Fishdom 5 │
# │            ┆ - Game     ┆ included   ┆ your own  ┆   ┆       ┆ Fishdom 5 ┆ ection    ┆ PC Game   │
# │            ┆ Pack - PC  ┆ everything ┆ aquarium  ┆   ┆       ┆ - Game    ┆ includes  ┆           │
# │            ┆            ┆ in…        ┆           ┆   ┆       ┆ Pack…     ┆ all f…    ┆           │
# │ B07HRWKLXX ┆ Obeka      ┆ Our soft   ┆ GOOD COMP ┆ … ┆       ┆ Product:  ┆ Enhance   ┆ Obeka     │
# │            ┆ Compatible ┆ case cover ┆ ATIBILITY ┆   ┆       ┆ Obeka Com ┆ your Xbox ┆ Silicone  │
# │            ┆ with Soft  ┆ will add   ┆ - Our     ┆   ┆       ┆ patible   ┆ One Elite ┆ Cover     │
# │            ┆ Ant…       ┆ a…         ┆ silic…    ┆   ┆       ┆ with…     ┆ Co…       ┆ Case      │
# │            ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆ with…     │
# └────────────┴────────────┴────────────┴───────────┴───┴───────┴───────────┴───────────┴───────────┘

# %%
item_df.head()
# Out:
# shape: (5, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────┬───────────┬───────────┬───────────┐
# │ parent_asi ┆ original_t ┆ original_d ┆ features_ ┆ … ┆ price ┆ item_cont ┆ descripti ┆ title     │
# │ n          ┆ itle       ┆ escription ┆ text      ┆   ┆ ---   ┆ ext       ┆ on_text   ┆ ---       │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ str   ┆ ---       ┆ ---       ┆ str       │
# │ str        ┆ str        ┆ str        ┆ str       ┆   ┆       ┆ str       ┆ str       ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════╪═══════════╪═══════════╪═══════════╡
# │ B00CX6FZCC ┆ DeadPool   ┆ There are  ┆           ┆ … ┆       ┆ Product:  ┆ Step into ┆ Deadpool  │
# │            ┆ [Online    ┆ a few      ┆           ┆   ┆       ┆ DeadPool  ┆ the role  ┆ Digital   │
# │            ┆ Game Code] ┆ important  ┆           ┆   ┆       ┆ [Online   ┆ of a      ┆ Game Code │
# │            ┆            ┆ thin…      ┆           ┆   ┆       ┆ Game…     ┆ mercen…   ┆           │
# │ B07XM5HSGK ┆ HUYUN USB  ┆ Replacemen ┆ 100% New  ┆ … ┆ 9.99  ┆ Product:  ┆ This is a ┆ Razer Dea │
# │            ┆ Mouse      ┆ t for      ┆ High      ┆   ┆       ┆ HUYUN USB ┆ replaceme ┆ thAdder   │
# │            ┆ Cable Wire ┆ Razer      ┆ quality   ┆   ┆       ┆ Mouse     ┆ nt mouse  ┆ 3.5G 2013 │
# │            ┆ & F…       ┆ DeathAdd…  ┆ USB mous… ┆   ┆       ┆ Cable…    ┆ ca…       ┆ Chr…      │
# │ B001EDF55W ┆ RS3 -      ┆ Buckle up  ┆ Featuring ┆ … ┆ 7.42  ┆ Product:  ┆ Experienc ┆ RS3       │
# │            ┆ Racing     ┆ and strap  ┆ 6 breatht ┆   ┆       ┆ RS3 -     ┆ e the     ┆ Racing    │
# │            ┆ Simulation ┆ yourself   ┆ aking     ┆   ┆       ┆ Racing    ┆ most puls ┆ Simulatio │
# │            ┆ Three      ┆ i…         ┆ racin…    ┆   ┆       ┆ Simulati… ┆ e-poun…   ┆ n Three   │
# │ B004H0LQO8 ┆ Fishdom 5  ┆ We have    ┆ Build     ┆ … ┆       ┆ Product:  ┆ This coll ┆ Fishdom 5 │
# │            ┆ - Game     ┆ included   ┆ your own  ┆   ┆       ┆ Fishdom 5 ┆ ection    ┆ PC Game   │
# │            ┆ Pack - PC  ┆ everything ┆ aquarium  ┆   ┆       ┆ - Game    ┆ includes  ┆           │
# │            ┆            ┆ in…        ┆           ┆   ┆       ┆ Pack…     ┆ all f…    ┆           │
# │ B07HRWKLXX ┆ Obeka      ┆ Our soft   ┆ GOOD COMP ┆ … ┆       ┆ Product:  ┆ Enhance   ┆ Obeka     │
# │            ┆ Compatible ┆ case cover ┆ ATIBILITY ┆   ┆       ┆ Obeka Com ┆ your Xbox ┆ Silicone  │
# │            ┆ with Soft  ┆ will add   ┆ - Our     ┆   ┆       ┆ patible   ┆ One Elite ┆ Cover     │
# │            ┆ Ant…       ┆ a…         ┆ silic…    ┆   ┆       ┆ with…     ┆ Co…       ┆ Case      │
# │            ┆            ┆            ┆           ┆   ┆       ┆           ┆           ┆ with…     │
# └────────────┴────────────┴────────────┴───────────┴───┴───────┴───────────┴───────────┴───────────┘

# %%
item_df = item_df.with_columns(
    pl.concat_str(
        [
            pl.lit("Title: "),
            pl.col("title"),
            pl.lit("\nDescription: "),
            pl.col("description_text"),
            pl.lit("\nCategory: "),
            pl.col("categories_text"),
            pl.lit("\nFeatures: "),
            pl.col("features_text"),
        ]
    ).alias("item_context")
)

# %%
contexts = item_df.select("item_context").head(2).to_series()
for c in contexts:
    print(c)
    print("------")
# Out:
# Title: Deadpool Digital Game Code
# Description: Step into the role of a mercenary with an accelerated healing factor in this third-person action-shooter. Battle for the safety of humans and mutants, wielding a devastating arsenal that includes katanas, guns, and explosives. String together satisfying combos and eviscerate your enemies with your impressive combat skills. Your X-Men pals also make an appearance, adding to the excitement. **System Requirements:** * **OS:** Windows XP, Vista, 7, or 8 * **Processor:** Intel Core 2 Duo E8200 @ 2.66 GHz or AMD Phenom X3 8750 * **RAM:** 2GB * **Hard Drive:** 6.6 GB Free Space * **Video Card:** GeForce 8800 GT or ATI Radeon HD4850 (512MB RAM) * **Additional:** DirectX 9.0c or later Requires Steam Client to activate.
# Category: Video Games > PC > Games
# Features:
# ------
# Title: Razer DeathAdder 3.5G 2013 Chroma Overwatch Mouse USB Cable Wire & Mouse Feet Replacement
# Description: This is a replacement mouse cable and mouse feet set designed for specific Razer DeathAdder models, including the DeathAdder 3500dpi (RZ01-0015), DeathAdder Chroma (RZ01-0121), and DeathAdder 2013 6400dpi (RZ01-0084) Gaming Mice. The black mouse cable features a total length of approximately 2.1 meters (82.68 inches). It has a 5-wire, 5-pin connection and uses a USB interface. The package includes one mouse cable and one set of Teflon mouse feet skates.
# Category: Video Games > PC > Accessories > Gaming Mice
# Features: 100% New High quality USB mouse cable Replacement For Razer DeathAdder / 2013 / Chroma/3.5G/1800DPI mouse Braided wire, durable Solve if you find your cable is broken or poor contact Package includes:1 piece mouse cable +1 set feet Skates Teflon
# ------

# %% [markdown]
# # Initialize Gemini client

# %%
client = genai.Client()
logger.info("Gemini client initialized successfully")
# Out:
# 10:13:21 - Gemini client initialized successfully

# %%
try:
    test_response = client.models.generate_content(
        model=MODEL, contents="Say 'API connection successful' if you can read this."
    )
    logger.info(f"API Test: {test_response.text}")
except Exception as e:
    logger.error(f"Failed to initialize Gemini client: {e}")
    logger.error("Please ensure GEMINI_API_KEY environment variable is set")
    raise
# Out:
# 10:13:26 - API Test: API connection successful

# %% [markdown]
# ## 4. Define Metadata Extraction Functions

# %%
PROMPT = """
Extract structured metadata from the following video game product information. 
Analyze the title, description, category, and features to identify key attributes.

Product Information:
<product>
{item}
</product>

Return ONLY a JSON object with the following fields (use null for unknown/not applicable):
{{
  "product_type": "Game|Hardware|Accessory|DLC|Bundle|<other relevant type>|null",
  "platform": ["PS5", "PS4", "Xbox Series X", "Xbox One", "Nintendo Switch", "PC", "Steam Deck", <other platforms>] or null,
  "genre": ["Action", "RPG", "Strategy", "Sports", "Racing", "Roguelike", "Soulslike", "Metroidvania", "Battle Royale", "MOBA", "Auto Battler", "Gacha", "Idle", "Tower Defense", <any other relevant genres/subgenres>] or null for non-games,
  "hardware_type": "Console|Controller|Headset|Cable|Storage|Skin|Stand|Cooling|Capture Card|<other hardware types>|null" for non-hardware,
  "brand": "Primary manufacturer or brand name" or null,
  "multiplayer": "Single-player|Local Co-op|Online Multiplayer|MMO|MMORPG|PvP|PvE|Couch Co-op|<other multiplayer modes>|null",
  "franchise": "Game series or franchise name if applicable" or null,
}}

Guidelines:
- Use arrays for fields that can have multiple values (especially for genre and platform)
- Keep values concise but descriptive
- For platform, use common abbreviations (PS5, Xbox One, Switch, etc.)
- For genres, be SPECIFIC and COMPREHENSIVE:
  * Include main genres AND subgenres (e.g., ["RPG", "JRPG", "Turn-based"])
  * Use modern gaming terminology (Roguelike, Soulslike, Metroidvania, Battle Royale, etc.)
  * Include thematic descriptors when relevant (Open World, Sandbox, Survival, Horror, etc.)
  * Can combine multiple descriptors (e.g., "Open World MMORPG", "Tactical Turn-based RPG")
- Feel free to use gaming-specific terms that accurately describe the product
- The examples shown are NOT exhaustive - use whatever terms best describe the product
- Return valid JSON only
""".strip()

# %%
# EXTRACT METADATA
def extract_metadata(prompt: str, item: str, model: str = MODEL) -> dict:
    """
    Extract metadata from item context using Gemini API.

    Args:
        prompt: The extraction instructions prompt
        item: The product context to analyze
        model: The Gemini model to use (defaults to MODEL constant)

    Returns:
        Dictionary of extracted metadata or None if failed
    """
    attempt = 0
    while attempt < MAX_RETRIES:
        try:
            # Format the full prompt with the item context
            full_prompt = prompt.format(item=item)

            # Generate content using Gemini
            response = client.models.generate_content(model=model, contents=full_prompt)

            # Parse JSON response
            response_text = response.text.strip()

            # Clean up markdown code blocks if present
            if response_text.startswith("```json"):
                response_text = response_text[7:]
            if response_text.startswith("```"):
                response_text = response_text[3:]
            if response_text.endswith("```"):
                response_text = response_text[:-3]

            # Parse the JSON
            metadata = json.loads(response_text.strip())

            # Validate that we got a dictionary with expected structure
            if isinstance(metadata, dict):
                return metadata
            else:
                attempt += 1
                if attempt < MAX_RETRIES:
                    logger.warning(f"Invalid response structure, retrying... (attempt {attempt}/{MAX_RETRIES})")
                    time.sleep(RETRY_DELAY)
                continue

        except json.JSONDecodeError as e:
            attempt += 1
            if attempt < MAX_RETRIES:
                logger.warning(f"JSON parse error: {e}, retrying... (attempt {attempt}/{MAX_RETRIES})")
                time.sleep(RETRY_DELAY)
            else:
                logger.error(f"Failed to parse JSON after {MAX_RETRIES} attempts")
                return None
        except Exception as e:
            attempt += 1
            if attempt < MAX_RETRIES:
                logger.warning(f"Error extracting metadata: {e}, retrying... (attempt {attempt}/{MAX_RETRIES})")
                time.sleep(RETRY_DELAY)
            else:
                logger.error(f"Failed after {MAX_RETRIES} attempts: {e}")
                return None

    return None


# Test the function with a sample item
test_item = item_df.head(1).select("item_context").item()
metadata = extract_metadata(PROMPT, test_item)
logger.info(f"Sample item context (first 200 chars): {test_item[:200]}...")
logger.info(f"Extracted metadata: {json.dumps(metadata, indent=2)}")
# Out:
# 10:17:18 - Sample item context (first 200 chars): Title: Deadpool Digital Game Code
# Description: Step into the role of a mercenary with an accelerated healing factor in this third-person action-shooter. Battle for the safety of humans and mutants, wi...
# 10:17:18 - Extracted metadata: {
#   "product_type": "Game",
#   "platform": [
#     "PC"
#   ],
#   "genre": [
#     "Action",
#     "Third-person Shooter",
#     "Action-Adventure"
#   ],
#   "hardware_type": null,
#   "brand": null,
#   "multiplayer": "Single-player",
#   "franchise": "Deadpool"
# }

# %% [markdown]
# ## 5. Parallel Metadata Extraction with Checkpointing

# %%
# Setup checkpoint file (using JSONL for structured data)
checkpoint_file = DATA_DIR / "output" / f"{CATEGORY}_metadata.jsonl"

# Load existing processed ASINs if checkpoint exists
processed_asins = set()
if checkpoint_file.exists():
    try:
        with open(checkpoint_file, "r", encoding="utf-8") as f:
            for line in f:
                if line.strip():
                    data = json.loads(line)
                    processed_asins.add(data["parent_asin"])
        logger.info(f"Found {len(processed_asins):,} already processed items in checkpoint file")
    except Exception as e:
        logger.error(f"Error loading checkpoint: {e}")
        processed_asins = set()
else:
    # Create new empty JSONL file
    checkpoint_file.touch()
    logger.info(f"Created new checkpoint file: {checkpoint_file}")

# Filter to only unprocessed items
items_to_process = item_df.filter(~pl.col("parent_asin").is_in(processed_asins))
logger.info(f"Items to process: {len(items_to_process):,} out of {len(item_df):,} total items")

# Thread-safe file writing lock
file_lock = threading.Lock()


def process_single_item(item_data):
    """Process a single item and extract metadata."""
    asin, item_context = item_data

    try:
        # Extract metadata
        metadata = extract_metadata(PROMPT, item_context)

        if metadata:
            # Create result with ASIN
            result = {"parent_asin": asin, **metadata}

            # Write immediately to JSONL with lock
            with file_lock:
                with open(checkpoint_file, "a", encoding="utf-8") as f:
                    f.write(json.dumps(result) + "\n")

            # Rate limiting
            time.sleep(RATE_LIMIT_DELAY)
            return asin, metadata, True
        else:
            # Log failed extraction
            logger.warning(f"Failed to extract metadata for {asin}")

            # Write null result to maintain record
            result = {"parent_asin": asin, "extraction_failed": True}
            with file_lock:
                with open(checkpoint_file, "a", encoding="utf-8") as f:
                    f.write(json.dumps(result) + "\n")

            return asin, None, False

    except Exception as e:
        logger.error(f"Failed to process {asin}: {e}")
        # Write error record
        result = {"parent_asin": asin, "error": str(e)}
        with file_lock:
            with open(checkpoint_file, "a", encoding="utf-8") as f:
                f.write(json.dumps(result) + "\n")
        return asin, None, False


# Prepare items for processing
items = [(row["parent_asin"], row["item_context"]) for row in items_to_process.iter_rows(named=True)]

if len(items) > 0:
    logger.info(f"Starting parallel processing with {MAX_THREADS} workers...")

    # Process with ThreadPoolExecutor
    successful = 0
    failed = 0

    with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
        # Submit all tasks
        futures = {executor.submit(process_single_item, item): item for item in items}

        # Process completions with progress bar
        with tqdm(total=len(futures), desc="Extracting metadata") as pbar:
            for future in as_completed(futures):
                try:
                    asin, result, success = future.result()
                    if success:
                        successful += 1
                    else:
                        failed += 1
                    pbar.update(1)
                    pbar.set_postfix({"success": successful, "failed": failed})

                except Exception as e:
                    failed += 1
                    pbar.update(1)
                    pbar.set_postfix({"success": successful, "failed": failed})
                    logger.error(f"Future failed: {e}")

    logger.info(f"Processing complete! Successful: {successful:,}, Failed: {failed:,}")

else:
    logger.info("No items to process - all items already in checkpoint file!")
# Out:
# 11:44:28 - Found 66,118 already processed items in checkpoint file
# 11:44:28 - Items to process: 0 out of 66,118 total items
# 11:44:28 - No items to process - all items already in checkpoint file!

# %%
# Load and verify the extracted metadata
if checkpoint_file.exists():
    # Load JSONL file into a list of dictionaries
    metadata_records = []
    with open(checkpoint_file, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                try:
                    metadata_records.append(json.loads(line))
                except json.JSONDecodeError as e:
                    logger.warning(f"Skipping invalid JSON line: {e}")

    logger.info(f"Loaded {len(metadata_records):,} metadata records from {checkpoint_file}")

    # Display sample of extracted metadata
    logger.info("Sample of extracted metadata:")
    for i, record in enumerate(metadata_records[:3]):
        logger.info(f"\nItem {i + 1} (ASIN: {record.get('parent_asin', 'N/A')}):")
        for key, value in record.items():
            if key != "parent_asin":
                logger.info(f"  {key}: {value}")

    # Analyze metadata coverage without converting to DataFrame first
    logger.info("\nMetadata field coverage:")
    field_counts = {}
    for record in metadata_records:
        for key, value in record.items():
            if key not in ["parent_asin", "extraction_failed", "error"]:
                if key not in field_counts:
                    field_counts[key] = 0
                if value is not None:
                    field_counts[key] += 1

    for field, count in sorted(field_counts.items()):
        coverage = (count / len(metadata_records)) * 100
        logger.info(f"  {field}: {count:,} / {len(metadata_records):,} ({coverage:.1f}%)")

    # Analyze product types
    logger.info("\nProduct type distribution:")
    product_type_counts = {}
    for record in metadata_records:
        pt = record.get("product_type")
        if pt:
            product_type_counts[pt] = product_type_counts.get(pt, 0) + 1

    for pt, count in sorted(product_type_counts.items(), key=lambda x: x[1], reverse=True)[:10]:
        logger.info(f"  {pt}: {count:,}")

    # Analyze platforms (handling arrays)
    logger.info("\nPlatform distribution (flattened):")
    platform_counts = {}
    for record in metadata_records:
        platforms = record.get("platform")
        if platforms:
            if isinstance(platforms, list):
                for p in platforms:
                    platform_counts[p] = platform_counts.get(p, 0) + 1
            else:
                platform_counts[platforms] = platform_counts.get(platforms, 0) + 1

    for platform, count in sorted(platform_counts.items(), key=lambda x: x[1], reverse=True)[:15]:
        logger.info(f"  {platform}: {count:,}")

    # Analyze genres (handling arrays)
    logger.info("\nGenre distribution (flattened):")
    genre_counts = {}
    for record in metadata_records:
        genres = record.get("genre")
        if genres:
            if isinstance(genres, list):
                for g in genres:
                    genre_counts[g] = genre_counts.get(g, 0) + 1
            else:
                genre_counts[genres] = genre_counts.get(genres, 0) + 1

    for genre, count in sorted(genre_counts.items(), key=lambda x: x[1], reverse=True)[:20]:
        logger.info(f"  {genre}: {count:,}")

    # Show multiplayer modes distribution
    logger.info("\nMultiplayer mode distribution:")
    multiplayer_counts = {}
    for record in metadata_records:
        mp = record.get("multiplayer")
        if mp:
            if isinstance(mp, list):
                for m in mp:
                    multiplayer_counts[m] = multiplayer_counts.get(m, 0) + 1
            else:
                multiplayer_counts[mp] = multiplayer_counts.get(mp, 0) + 1

    for mp_mode, count in sorted(multiplayer_counts.items(), key=lambda x: x[1], reverse=True)[:10]:
        logger.info(f"  {mp_mode}: {count:,}")

else:
    logger.warning("No checkpoint file found. Run the processing cell first.")
# Out:
# 11:44:39 - Loaded 66,118 metadata records from /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_metadata.jsonl
# 11:44:39 - Sample of extracted metadata:
# 11:44:39 -
# Item 1 (ASIN: B001EDF55W):
# 11:44:39 -   product_type: Game
# 11:44:39 -   platform: ['PC']
# 11:44:39 -   genre: ['Simulation', 'Racing', 'Sports']
# 11:44:39 -   hardware_type: None
# 11:44:39 -   brand: None
# 11:44:39 -   multiplayer: Single-player
# 11:44:39 -   franchise: None
# 11:44:39 -
# Item 2 (ASIN: B08S7MCMM2):
# 11:44:39 -   product_type: Accessory
# 11:44:39 -   platform: ['PS5']
# 11:44:39 -   genre: None
# 11:44:39 -   hardware_type: Controller
# 11:44:39 -   brand: OLOPE
# 11:44:39 -   multiplayer: None
# 11:44:39 -   franchise: None
# 11:44:39 -
# Item 3 (ASIN: B001ELJP4G):
# 11:44:39 -   product_type: Accessory
# 11:44:39 -   platform: ['Wii']
# 11:44:39 -   genre: ['Racing']
# 11:44:39 -   hardware_type: Controller
# 11:44:39 -   brand: dreamGEAR
# 11:44:39 -   multiplayer: None
# 11:44:39 -   franchise: None
# 11:44:39 -
# Metadata field coverage:
# 11:44:39 -   DLCs: 1 / 66,118 (0.0%)
# 11:44:39 -   abilities: 1 / 66,118 (0.0%)
# 11:44:39 -   accessibility_features: 0 / 66,118 (0.0%)
# 11:44:39 -   accessories: 28 / 66,118 (0.0%)
# 11:44:39 -   accessories_for_device: 1 / 66,118 (0.0%)
# 11:44:39 -   accessories_included: 12 / 66,118 (0.0%)
# 11:44:39 -   accessories_required: 3 / 66,118 (0.0%)
# 11:44:39 -   accessory_bundle: 1 / 66,118 (0.0%)
# 11:44:39 -   accessory_for: 1 / 66,118 (0.0%)
# 11:44:39 -   accessory_part: 1 / 66,118 (0.0%)
# 11:44:39 -   accessory_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   accessory_type: 8 / 66,118 (0.0%)
# 11:44:39 -   achievements_per_level: 1 / 66,118 (0.0%)
# 11:44:39 -   activation: 1 / 66,118 (0.0%)
# 11:44:39 -   activation_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   activation_requirements: 3 / 66,118 (0.0%)
# 11:44:39 -   add_on_for: 1 / 66,118 (0.0%)
# 11:44:39 -   add_on_name: 1 / 66,118 (0.0%)
# 11:44:39 -   add_on_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   add_ons: 1 / 66,118 (0.0%)
# 11:44:39 -   additional_attributes: 11 / 66,118 (0.0%)
# 11:44:39 -   additional_content: 4 / 66,118 (0.0%)
# 11:44:39 -   additional_details: 11 / 66,118 (0.0%)
# 11:44:39 -   additional_features: 9 / 66,118 (0.0%)
# 11:44:39 -   additional_games_included: 1 / 66,118 (0.0%)
# 11:44:39 -   additional_hardware_included: 1 / 66,118 (0.0%)
# 11:44:39 -   additional_info: 12 / 66,118 (0.0%)
# 11:44:39 -   additional_information: 2 / 66,118 (0.0%)
# 11:44:39 -   additional_items: 2 / 66,118 (0.0%)
# 11:44:39 -   additional_metadata: 3 / 66,118 (0.0%)
# 11:44:39 -   additional_notes: 2 / 66,118 (0.0%)
# 11:44:39 -   additional_properties: 2 / 66,118 (0.0%)
# 11:44:39 -   additional_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   additional_tools: 1 / 66,118 (0.0%)
# 11:44:39 -   after_sales_service: 1 / 66,118 (0.0%)
# 11:44:39 -   age_range: 5 / 66,118 (0.0%)
# 11:44:39 -   age_rating: 33 / 66,118 (0.0%)
# 11:44:39 -   ages: 2 / 66,118 (0.0%)
# 11:44:39 -   aircraft_family: 1 / 66,118 (0.0%)
# 11:44:39 -   amiibo_included: 1 / 66,118 (0.0%)
# 11:44:39 -   analysis: 1 / 66,118 (0.0%)
# 11:44:39 -   antagonists: 1 / 66,118 (0.0%)
# 11:44:39 -   art_style: 0 / 66,118 (0.0%)
# 11:44:39 -   artist_list: 1 / 66,118 (0.0%)
# 11:44:39 -   artists: 1 / 66,118 (0.0%)
# 11:44:39 -   aspect_ratios: 1 / 66,118 (0.0%)
# 11:44:39 -   assembly_required: 1 / 66,118 (0.0%)
# 11:44:39 -   associated_artist: 1 / 66,118 (0.0%)
# 11:44:39 -   associated_game: 1 / 66,118 (0.0%)
# 11:44:39 -   atk: 3 / 66,118 (0.0%)
# 11:44:39 -   attribute: 3 / 66,118 (0.0%)
# 11:44:39 -   attributes: 6 / 66,118 (0.0%)
# 11:44:39 -   audio: 2 / 66,118 (0.0%)
# 11:44:39 -   audio_features: 3 / 66,118 (0.0%)
# 11:44:39 -   audio_formats: 0 / 66,118 (0.0%)
# 11:44:39 -   audio_language: 1 / 66,118 (0.0%)
# 11:44:39 -   audio_languages: 0 / 66,118 (0.0%)
# 11:44:39 -   audio_options: 1 / 66,118 (0.0%)
# 11:44:39 -   audio_output: 3 / 66,118 (0.0%)
# 11:44:39 -   authenticity: 1 / 66,118 (0.0%)
# 11:44:39 -   av_cable_specifications: 1 / 66,118 (0.0%)
# 11:44:39 -   availability: 1 / 66,118 (0.0%)
# 11:44:39 -   base_game: 2 / 66,118 (0.0%)
# 11:44:39 -   base_game_required: 2 / 66,118 (0.0%)
# 11:44:39 -   battery: 1 / 66,118 (0.0%)
# 11:44:39 -   battery_capacity: 1 / 66,118 (0.0%)
# 11:44:39 -   battery_capacity_mAh: 1 / 66,118 (0.0%)
# 11:44:39 -   battery_capacity_mah: 2 / 66,118 (0.0%)
# 11:44:39 -   battery_life: 7 / 66,118 (0.0%)
# 11:44:39 -   battery_life_hours: 1 / 66,118 (0.0%)
# 11:44:39 -   battery_specifications: 1 / 66,118 (0.0%)
# 11:44:39 -   battery_specs: 3 / 66,118 (0.0%)
# 11:44:39 -   battery_type: 4 / 66,118 (0.0%)
# 11:44:39 -   battery_voltage: 3 / 66,118 (0.0%)
# 11:44:39 -   benefits: 1 / 66,118 (0.0%)
# 11:44:39 -   bit_sizes: 1 / 66,118 (0.0%)
# 11:44:39 -   bonus_content: 1 / 66,118 (0.0%)
# 11:44:39 -   brand: 51,285 / 66,118 (77.6%)
# 11:44:39 -   broadcast_talent: 1 / 66,118 (0.0%)
# 11:44:39 -   bundle_content: 1 / 66,118 (0.0%)
# 11:44:39 -   bundle_contents: 24 / 66,118 (0.0%)
# 11:44:39 -   bundle_details: 2 / 66,118 (0.0%)
# 11:44:39 -   bundle_includes: 2 / 66,118 (0.0%)
# 11:44:39 -   bundle_items: 2 / 66,118 (0.0%)
# 11:44:39 -   bundle_type: 0 / 66,118 (0.0%)
# 11:44:39 -   bundled_with: 0 / 66,118 (0.0%)
# 11:44:39 -   bundles: 0 / 66,118 (0.0%)
# 11:44:39 -   bundles_included: 1 / 66,118 (0.0%)
# 11:44:39 -   cable_length: 9 / 66,118 (0.0%)
# 11:44:39 -   cable_type: 1 / 66,118 (0.0%)
# 11:44:39 -   campaigns: 1 / 66,118 (0.0%)
# 11:44:39 -   capacity_mah: 4 / 66,118 (0.0%)
# 11:44:39 -   card_name: 2 / 66,118 (0.0%)
# 11:44:39 -   card_number: 1 / 66,118 (0.0%)
# 11:44:39 -   card_rarity: 1 / 66,118 (0.0%)
# 11:44:39 -   card_set: 1 / 66,118 (0.0%)
# 11:44:39 -   card_type: 4 / 66,118 (0.0%)
# 11:44:39 -   care_instructions: 1 / 66,118 (0.0%)
# 11:44:39 -   cargo_types: 1 / 66,118 (0.0%)
# 11:44:39 -   category: 264 / 66,118 (0.4%)
# 11:44:39 -   category_analysis: 2 / 66,118 (0.0%)
# 11:44:39 -   category_keywords: 1 / 66,118 (0.0%)
# 11:44:39 -   category_notes: 1 / 66,118 (0.0%)
# 11:44:39 -   category_path: 1 / 66,118 (0.0%)
# 11:44:39 -   certifications: 6 / 66,118 (0.0%)
# 11:44:39 -   character: 4 / 66,118 (0.0%)
# 11:44:39 -   character_count: 1 / 66,118 (0.0%)
# 11:44:39 -   character_creation: 1 / 66,118 (0.0%)
# 11:44:39 -   character_toys: 1 / 66,118 (0.0%)
# 11:44:39 -   character_voice_actors: 1 / 66,118 (0.0%)
# 11:44:39 -   characters: 6 / 66,118 (0.0%)
# 11:44:39 -   charge_speed: 1 / 66,118 (0.0%)
# 11:44:39 -   charger: 1 / 66,118 (0.0%)
# 11:44:39 -   charging_support: 1 / 66,118 (0.0%)
# 11:44:39 -   charging_time: 1 / 66,118 (0.0%)
# 11:44:39 -   charitable_donation: 1 / 66,118 (0.0%)
# 11:44:39 -   child_friendly: 1 / 66,118 (0.0%)
# 11:44:39 -   clarity: 1 / 66,118 (0.0%)
# 11:44:39 -   collectible_card_game: 1 / 66,118 (0.0%)
# 11:44:39 -   collectible_elements: 1 / 66,118 (0.0%)
# 11:44:39 -   collectible_items: 2 / 66,118 (0.0%)
# 11:44:39 -   collection_items: 1 / 66,118 (0.0%)
# 11:44:39 -   collection_name: 1 / 66,118 (0.0%)
# 11:44:39 -   collection_title: 1 / 66,118 (0.0%)
# 11:44:39 -   collector_edition: 9 / 66,118 (0.0%)
# 11:44:39 -   collector_edition_contents: 2 / 66,118 (0.0%)
# 11:44:39 -   collector_edition_details: 1 / 66,118 (0.0%)
# 11:44:39 -   collector_edition_extras: 1 / 66,118 (0.0%)
# 11:44:39 -   collector_items: 1 / 66,118 (0.0%)
# 11:44:39 -   collector_s_edition: 1 / 66,118 (0.0%)
# 11:44:39 -   collectors_edition: 3 / 66,118 (0.0%)
# 11:44:39 -   collectors_edition_contents: 2 / 66,118 (0.0%)
# 11:44:39 -   collectors_edition_features: 2 / 66,118 (0.0%)
# 11:44:39 -   collectors_edition_items: 1 / 66,118 (0.0%)
# 11:44:39 -   collectors_items: 1 / 66,118 (0.0%)
# 11:44:39 -   color: 51 / 66,118 (0.1%)
# 11:44:39 -   color_variation: 1 / 66,118 (0.0%)
# 11:44:39 -   colors: 1 / 66,118 (0.0%)
# 11:44:39 -   commanders: 1 / 66,118 (0.0%)
# 11:44:39 -   company: 1 / 66,118 (0.0%)
# 11:44:39 -   compatability: 1 / 66,118 (0.0%)
# 11:44:39 -   compatibilities: 1 / 66,118 (0.0%)
# 11:44:39 -   compatibility: 53 / 66,118 (0.1%)
# 11:44:39 -   compatibility_notes: 6 / 66,118 (0.0%)
# 11:44:39 -   compatible_console_model: 2 / 66,118 (0.0%)
# 11:44:39 -   compatible_consoles: 6 / 66,118 (0.0%)
# 11:44:39 -   compatible_controller_model: 1 / 66,118 (0.0%)
# 11:44:39 -   compatible_controller_models: 2 / 66,118 (0.0%)
# 11:44:39 -   compatible_controllers: 1 / 66,118 (0.0%)
# 11:44:39 -   compatible_device: 3 / 66,118 (0.0%)
# 11:44:39 -   compatible_devices: 8 / 66,118 (0.0%)
# 11:44:39 -   compatible_hardware: 2 / 66,118 (0.0%)
# 11:44:39 -   compatible_headsets: 1 / 66,118 (0.0%)
# 11:44:39 -   compatible_models: 7 / 66,118 (0.0%)
# 11:44:39 -   compatible_part_number: 1 / 66,118 (0.0%)
# 11:44:39 -   compatible_part_numbers: 2 / 66,118 (0.0%)
# 11:44:39 -   compatible_platform: 1 / 66,118 (0.0%)
# 11:44:39 -   compatible_sony_models: 1 / 66,118 (0.0%)
# 11:44:39 -   compatible_with: 11 / 66,118 (0.0%)
# 11:44:39 -   component_name: 1 / 66,118 (0.0%)
# 11:44:39 -   component_type: 2 / 66,118 (0.0%)
# 11:44:39 -   components: 2 / 66,118 (0.0%)
# 11:44:39 -   condition: 52 / 66,118 (0.1%)
# 11:44:39 -   condition_details: 1 / 66,118 (0.0%)
# 11:44:39 -   condition_notes: 2 / 66,118 (0.0%)
# 11:44:39 -   connection_type: 4 / 66,118 (0.0%)
# 11:44:39 -   connectivity: 13 / 66,118 (0.0%)
# 11:44:39 -   connector_type: 3 / 66,118 (0.0%)
# 11:44:39 -   connectors: 1 / 66,118 (0.0%)
# 11:44:39 -   console_generation: 1 / 66,118 (0.0%)
# 11:44:39 -   console_inclusion: 1 / 66,118 (0.0%)
# 11:44:39 -   console_specs: 2 / 66,118 (0.0%)
# 11:44:39 -   content: 1 / 66,118 (0.0%)
# 11:44:39 -   content_details: 3 / 66,118 (0.0%)
# 11:44:39 -   content_features: 1 / 66,118 (0.0%)
# 11:44:39 -   content_focus: 1 / 66,118 (0.0%)
# 11:44:39 -   content_included: 2 / 66,118 (0.0%)
# 11:44:39 -   content_rating: 0 / 66,118 (0.0%)
# 11:44:39 -   content_summary: 1 / 66,118 (0.0%)
# 11:44:39 -   content_type: 5 / 66,118 (0.0%)
# 11:44:39 -   content_warnings: 1 / 66,118 (0.0%)
# 11:44:39 -   control_features: 2 / 66,118 (0.0%)
# 11:44:39 -   controller_details: 1 / 66,118 (0.0%)
# 11:44:39 -   controller_included: 1 / 66,118 (0.0%)
# 11:44:39 -   controller_modification_type: 1 / 66,118 (0.0%)
# 11:44:39 -   controller_required: 1 / 66,118 (0.0%)
# 11:44:39 -   controller_support: 0 / 66,118 (0.0%)
# 11:44:39 -   controller_type: 1 / 66,118 (0.0%)
# 11:44:39 -   controllers: 0 / 66,118 (0.0%)
# 11:44:39 -   controllers_included: 2 / 66,118 (0.0%)
# 11:44:39 -   copyright_year: 1 / 66,118 (0.0%)
# 11:44:39 -   cover_athletes: 1 / 66,118 (0.0%)
# 11:44:39 -   critic_reviews: 1 / 66,118 (0.0%)
# 11:44:39 -   cross_platform: 0 / 66,118 (0.0%)
# 11:44:39 -   cross_platform_multiplayer: 1 / 66,118 (0.0%)
# 11:44:39 -   cross_play: 0 / 66,118 (0.0%)
# 11:44:39 -   cross_save: 0 / 66,118 (0.0%)
# 11:44:39 -   currency: 4 / 66,118 (0.0%)
# 11:44:39 -   currency_amount: 1 / 66,118 (0.0%)
# 11:44:39 -   currency_type: 6 / 66,118 (0.0%)
# 11:44:39 -   customer_support: 1 / 66,118 (0.0%)
# 11:44:39 -   customization: 1 / 66,118 (0.0%)
# 11:44:39 -   data_transfer_speed: 1 / 66,118 (0.0%)
# 11:44:39 -   def: 3 / 66,118 (0.0%)
# 11:44:39 -   denominations: 1 / 66,118 (0.0%)
# 11:44:39 -   dependencies: 1 / 66,118 (0.0%)
# 11:44:39 -   description: 435 / 66,118 (0.7%)
# 11:44:39 -   description_analysis: 6 / 66,118 (0.0%)
# 11:44:39 -   description_content: 1 / 66,118 (0.0%)
# 11:44:39 -   description_details: 4 / 66,118 (0.0%)
# 11:44:39 -   description_en: 1 / 66,118 (0.0%)
# 11:44:39 -   description_extra: 2 / 66,118 (0.0%)
# 11:44:39 -   description_extracted_features: 1 / 66,118 (0.0%)
# 11:44:39 -   description_features: 6 / 66,118 (0.0%)
# 11:44:39 -   description_keywords: 18 / 66,118 (0.0%)
# 11:44:39 -   description_metadata: 1 / 66,118 (0.0%)
# 11:44:39 -   description_notes: 1 / 66,118 (0.0%)
# 11:44:39 -   description_raw: 1 / 66,118 (0.0%)
# 11:44:39 -   description_short: 1 / 66,118 (0.0%)
# 11:44:39 -   description_summary: 2 / 66,118 (0.0%)
# 11:44:39 -   description_text: 4 / 66,118 (0.0%)
# 11:44:39 -   design: 2 / 66,118 (0.0%)
# 11:44:39 -   design_features: 1 / 66,118 (0.0%)
# 11:44:39 -   design_theme: 1 / 66,118 (0.0%)
# 11:44:39 -   details: 30 / 66,118 (0.0%)
# 11:44:39 -   developer: 49 / 66,118 (0.1%)
# 11:44:39 -   developer_url: 0 / 66,118 (0.0%)
# 11:44:39 -   developers: 4 / 66,118 (0.0%)
# 11:44:39 -   device_type: 1 / 66,118 (0.0%)
# 11:44:39 -   difficulty: 1 / 66,118 (0.0%)
# 11:44:39 -   difficulty_levels: 2 / 66,118 (0.0%)
# 11:44:39 -   digital_code: 6 / 66,118 (0.0%)
# 11:44:39 -   digital_code_included: 1 / 66,118 (0.0%)
# 11:44:39 -   digital_code_platform: 1 / 66,118 (0.0%)
# 11:44:39 -   digital_code_required: 1 / 66,118 (0.0%)
# 11:44:39 -   digital_content: 1 / 66,118 (0.0%)
# 11:44:39 -   digital_delivery_method: 1 / 66,118 (0.0%)
# 11:44:39 -   digital_download: 0 / 66,118 (0.0%)
# 11:44:39 -   digital_format: 1 / 66,118 (0.0%)
# 11:44:39 -   digital_media: 0 / 66,118 (0.0%)
# 11:44:39 -   digital_only: 2 / 66,118 (0.0%)
# 11:44:39 -   digital_storefront: 0 / 66,118 (0.0%)
# 11:44:39 -   dimensions: 10 / 66,118 (0.0%)
# 11:44:39 -   dimensions_mm: 1 / 66,118 (0.0%)
# 11:44:39 -   director: 1 / 66,118 (0.0%)
# 11:44:39 -   directx_version: 1 / 66,118 (0.0%)
# 11:44:39 -   disc_count: 1 / 66,118 (0.0%)
# 11:44:39 -   disc_format: 1 / 66,118 (0.0%)
# 11:44:39 -   disc_type: 1 / 66,118 (0.0%)
# 11:44:39 -   display_features: 1 / 66,118 (0.0%)
# 11:44:39 -   display_name: 2 / 66,118 (0.0%)
# 11:44:39 -   display_output: 0 / 66,118 (0.0%)
# 11:44:39 -   display_resolution: 1 / 66,118 (0.0%)
# 11:44:39 -   display_size: 1 / 66,118 (0.0%)
# 11:44:39 -   display_technology: 1 / 66,118 (0.0%)
# 11:44:39 -   display_type: 1 / 66,118 (0.0%)
# 11:44:39 -   distribution_method: 1 / 66,118 (0.0%)
# 11:44:39 -   dlc: 9 / 66,118 (0.0%)
# 11:44:39 -   dlc_available: 0 / 66,118 (0.0%)
# 11:44:39 -   dlc_content: 3 / 66,118 (0.0%)
# 11:44:39 -   dlc_details: 1 / 66,118 (0.0%)
# 11:44:39 -   dlc_expansions: 1 / 66,118 (0.0%)
# 11:44:39 -   dlc_included: 24 / 66,118 (0.0%)
# 11:44:39 -   dlc_name: 3 / 66,118 (0.0%)
# 11:44:39 -   dlc_type: 2 / 66,118 (0.0%)
# 11:44:39 -   dock_specs: 1 / 66,118 (0.0%)
# 11:44:39 -   downloadable_content: 0 / 66,118 (0.0%)
# 11:44:39 -   drive_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   early_access: 1 / 66,118 (0.0%)
# 11:44:39 -   edition: 55 / 66,118 (0.1%)
# 11:44:39 -   edition_details: 1 / 66,118 (0.0%)
# 11:44:39 -   editor: 1 / 66,118 (0.0%)
# 11:44:39 -   editor_reviews: 0 / 66,118 (0.0%)
# 11:44:39 -   educational_focus: 3 / 66,118 (0.0%)
# 11:44:39 -   effect_description: 1 / 66,118 (0.0%)
# 11:44:39 -   effect_type: 1 / 66,118 (0.0%)
# 11:44:39 -   elements: 1 / 66,118 (0.0%)
# 11:44:39 -   engine: 11 / 66,118 (0.0%)
# 11:44:39 -   engine_technology: 1 / 66,118 (0.0%)
# 11:44:39 -   environments: 2 / 66,118 (0.0%)
# 11:44:39 -   era: 1 / 66,118 (0.0%)
# 11:44:39 -   esrb_content_description: 4 / 66,118 (0.0%)
# 11:44:39 -   esrb_descriptors: 1 / 66,118 (0.0%)
# 11:44:39 -   esrb_rating: 36 / 66,118 (0.1%)
# 11:44:39 -   esrb_rating_url: 0 / 66,118 (0.0%)
# 11:44:39 -   excluded_parts: 1 / 66,118 (0.0%)
# 11:44:39 -   exclusive_content: 1 / 66,118 (0.0%)
# 11:44:39 -   exclusives: 1 / 66,118 (0.0%)
# 11:44:39 -   expansion: 1 / 66,118 (0.0%)
# 11:44:39 -   expansion_content: 2 / 66,118 (0.0%)
# 11:44:39 -   expansion_for: 0 / 66,118 (0.0%)
# 11:44:39 -   expansion_included: 2 / 66,118 (0.0%)
# 11:44:39 -   expansion_name: 3 / 66,118 (0.0%)
# 11:44:39 -   expansion_pack: 4 / 66,118 (0.0%)
# 11:44:39 -   expansion_pack_for: 1 / 66,118 (0.0%)
# 11:44:39 -   expansion_packs: 3 / 66,118 (0.0%)
# 11:44:39 -   expansion_pak_required: 1 / 66,118 (0.0%)
# 11:44:39 -   expansions: 2 / 66,118 (0.0%)
# 11:44:39 -   extra_features: 1 / 66,118 (0.0%)
# 11:44:39 -   faction: 1 / 66,118 (0.0%)
# 11:44:39 -   feature_highlights: 1 / 66,118 (0.0%)
# 11:44:39 -   feature_keywords: 2 / 66,118 (0.0%)
# 11:44:39 -   feature_list: 1 / 66,118 (0.0%)
# 11:44:39 -   features: 1,551 / 66,118 (2.3%)
# 11:44:39 -   features_analysis: 3 / 66,118 (0.0%)
# 11:44:39 -   features_en: 1 / 66,118 (0.0%)
# 11:44:39 -   features_included: 2 / 66,118 (0.0%)
# 11:44:39 -   features_keywords: 1 / 66,118 (0.0%)
# 11:44:39 -   features_list: 1 / 66,118 (0.0%)
# 11:44:39 -   file_size_gb: 1 / 66,118 (0.0%)
# 11:44:39 -   finish: 1 / 66,118 (0.0%)
# 11:44:39 -   firmware_upgradeable: 1 / 66,118 (0.0%)
# 11:44:39 -   fish_species: 1 / 66,118 (0.0%)
# 11:44:39 -   form_factor: 1 / 66,118 (0.0%)
# 11:44:39 -   format: 2 / 66,118 (0.0%)
# 11:44:39 -   framerate: 1 / 66,118 (0.0%)
# 11:44:39 -   franchise: 35,863 / 66,118 (54.2%)
# 11:44:39 -   free_with_coupon: 1 / 66,118 (0.0%)
# 11:44:39 -   function: 1 / 66,118 (0.0%)
# 11:44:39 -   game: 0 / 66,118 (0.0%)
# 11:44:39 -   game_code_type: 1 / 66,118 (0.0%)
# 11:44:39 -   game_content: 1 / 66,118 (0.0%)
# 11:44:39 -   game_count: 2 / 66,118 (0.0%)
# 11:44:39 -   game_creation_tools: 1 / 66,118 (0.0%)
# 11:44:39 -   game_currency: 1 / 66,118 (0.0%)
# 11:44:39 -   game_details: 4 / 66,118 (0.0%)
# 11:44:39 -   game_edition: 9 / 66,118 (0.0%)
# 11:44:39 -   game_engine: 4 / 66,118 (0.0%)
# 11:44:39 -   game_engine_compatibility: 1 / 66,118 (0.0%)
# 11:44:39 -   game_features: 1 / 66,118 (0.0%)
# 11:44:39 -   game_format: 1 / 66,118 (0.0%)
# 11:44:39 -   game_format_support: 1 / 66,118 (0.0%)
# 11:44:39 -   game_included: 4 / 66,118 (0.0%)
# 11:44:39 -   game_mechanics: 3 / 66,118 (0.0%)
# 11:44:39 -   game_mode: 1 / 66,118 (0.0%)
# 11:44:39 -   game_modes: 56 / 66,118 (0.1%)
# 11:44:39 -   game_modes_dlc: 1 / 66,118 (0.0%)
# 11:44:39 -   game_name: 5 / 66,118 (0.0%)
# 11:44:39 -   game_required: 1 / 66,118 (0.0%)
# 11:44:39 -   game_series: 1 / 66,118 (0.0%)
# 11:44:39 -   game_specific: 1 / 66,118 (0.0%)
# 11:44:39 -   game_subgenre: 1 / 66,118 (0.0%)
# 11:44:39 -   game_title: 21 / 66,118 (0.0%)
# 11:44:39 -   game_titles: 5 / 66,118 (0.0%)
# 11:44:39 -   game_titles_compatible_with: 1 / 66,118 (0.0%)
# 11:44:39 -   game_type: 5 / 66,118 (0.0%)
# 11:44:39 -   game_version: 1 / 66,118 (0.0%)
# 11:44:39 -   gameplay_duration: 1 / 66,118 (0.0%)
# 11:44:39 -   gameplay_elements: 3 / 66,118 (0.0%)
# 11:44:39 -   gameplay_features: 9 / 66,118 (0.0%)
# 11:44:39 -   gameplay_mechanics: 14 / 66,118 (0.0%)
# 11:44:39 -   gameplay_modes: 1 / 66,118 (0.0%)
# 11:44:39 -   gameplay_style: 1 / 66,118 (0.0%)
# 11:44:39 -   games_included: 16 / 66,118 (0.0%)
# 11:44:39 -   genre: 32,970 / 66,118 (49.9%)
# 11:44:39 -   geography: 1 / 66,118 (0.0%)
# 11:44:39 -   gpu: 1 / 66,118 (0.0%)
# 11:44:39 -   graphics: 3 / 66,118 (0.0%)
# 11:44:39 -   graphics_api: 2 / 66,118 (0.0%)
# 11:44:39 -   graphics_api_compatibility: 1 / 66,118 (0.0%)
# 11:44:39 -   graphics_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   guarantee: 4 / 66,118 (0.0%)
# 11:44:39 -   hard_disk_space: 2 / 66,118 (0.0%)
# 11:44:39 -   hard_disk_space_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   hard_drive_space: 2 / 66,118 (0.0%)
# 11:44:39 -   hardware_details: 8 / 66,118 (0.0%)
# 11:44:39 -   hardware_included: 18 / 66,118 (0.0%)
# 11:44:39 -   hardware_required: 5 / 66,118 (0.0%)
# 11:44:39 -   hardware_requirements: 5 / 66,118 (0.0%)
# 11:44:39 -   hardware_specifics: 2 / 66,118 (0.0%)
# 11:44:39 -   hardware_type: 34,145 / 66,118 (51.6%)
# 11:44:39 -   hardware_type_specific: 1 / 66,118 (0.0%)
# 11:44:39 -   headset_model: 1 / 66,118 (0.0%)
# 11:44:39 -   historical_context: 1 / 66,118 (0.0%)
# 11:44:39 -   historical_period: 1 / 66,118 (0.0%)
# 11:44:39 -   host: 1 / 66,118 (0.0%)
# 11:44:39 -   import_status: 1 / 66,118 (0.0%)
# 11:44:39 -   in_app_purchases: 1 / 66,118 (0.0%)
# 11:44:39 -   in_game_currency: 1 / 66,118 (0.0%)
# 11:44:39 -   in_game_currency_amount: 2 / 66,118 (0.0%)
# 11:44:39 -   in_game_currency_type: 1 / 66,118 (0.0%)
# 11:44:39 -   in_game_purchases: 0 / 66,118 (0.0%)
# 11:44:39 -   included_accessories: 12 / 66,118 (0.0%)
# 11:44:39 -   included_components: 1 / 66,118 (0.0%)
# 11:44:39 -   included_content: 4 / 66,118 (0.0%)
# 11:44:39 -   included_dlc: 2 / 66,118 (0.0%)
# 11:44:39 -   included_features: 1 / 66,118 (0.0%)
# 11:44:39 -   included_games: 28 / 66,118 (0.0%)
# 11:44:39 -   included_hardware: 7 / 66,118 (0.0%)
# 11:44:39 -   included_items: 27 / 66,118 (0.0%)
# 11:44:39 -   included_locomotives: 1 / 66,118 (0.0%)
# 11:44:39 -   included_machines: 1 / 66,118 (0.0%)
# 11:44:39 -   included_merchandise: 1 / 66,118 (0.0%)
# 11:44:39 -   included_parts: 1 / 66,118 (0.0%)
# 11:44:39 -   included_players: 1 / 66,118 (0.0%)
# 11:44:39 -   included_routes: 1 / 66,118 (0.0%)
# 11:44:39 -   included_software: 4 / 66,118 (0.0%)
# 11:44:39 -   included_soundtracks: 1 / 66,118 (0.0%)
# 11:44:39 -   included_titles: 1 / 66,118 (0.0%)
# 11:44:39 -   included_tools: 2 / 66,118 (0.0%)
# 11:44:39 -   includes: 3 / 66,118 (0.0%)
# 11:44:39 -   includes_dlc: 3 / 66,118 (0.0%)
# 11:44:39 -   inclusions: 3 / 66,118 (0.0%)
# 11:44:39 -   incompatibility: 1 / 66,118 (0.0%)
# 11:44:39 -   incompatible_controller_models: 1 / 66,118 (0.0%)
# 11:44:39 -   incompatible_devices: 1 / 66,118 (0.0%)
# 11:44:39 -   incompatible_with: 1 / 66,118 (0.0%)
# 11:44:39 -   ingredients: 1 / 66,118 (0.0%)
# 11:44:39 -   input: 0 / 66,118 (0.0%)
# 11:44:39 -   input_devices_supported: 1 / 66,118 (0.0%)
# 11:44:39 -   input_method: 1 / 66,118 (0.0%)
# 11:44:39 -   input_methods: 0 / 66,118 (0.0%)
# 11:44:39 -   installation_method: 1 / 66,118 (0.0%)
# 11:44:39 -   installation_notes: 1 / 66,118 (0.0%)
# 11:44:39 -   installation_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   intended_use: 1 / 66,118 (0.0%)
# 11:44:39 -   interface: 1 / 66,118 (0.0%)
# 11:44:39 -   internal_storage: 1 / 66,118 (0.0%)
# 11:44:39 -   is_import: 1 / 66,118 (0.0%)
# 11:44:39 -   isbn: 1 / 66,118 (0.0%)
# 11:44:39 -   item_count: 2 / 66,118 (0.0%)
# 11:44:39 -   item_dimensions: 0 / 66,118 (0.0%)
# 11:44:39 -   item_name: 1 / 66,118 (0.0%)
# 11:44:39 -   item_number: 1 / 66,118 (0.0%)
# 11:44:39 -   item_specifics: 1 / 66,118 (0.0%)
# 11:44:39 -   item_type: 5 / 66,118 (0.0%)
# 11:44:39 -   item_weight: 0 / 66,118 (0.0%)
# 11:44:39 -   items: 2 / 66,118 (0.0%)
# 11:44:39 -   items_in_bundle: 1 / 66,118 (0.0%)
# 11:44:39 -   items_included: 1 / 66,118 (0.0%)
# 11:44:39 -   key_features: 9 / 66,118 (0.0%)
# 11:44:39 -   key_mechanics: 1 / 66,118 (0.0%)
# 11:44:39 -   kit_contents: 2 / 66,118 (0.0%)
# 11:44:39 -   lake_size_acres: 1 / 66,118 (0.0%)
# 11:44:39 -   landmarks_added: 1 / 66,118 (0.0%)
# 11:44:39 -   language: 8 / 66,118 (0.0%)
# 11:44:39 -   languages: 15 / 66,118 (0.0%)
# 11:44:39 -   length: 5 / 66,118 (0.0%)
# 11:44:39 -   length_ft: 1 / 66,118 (0.0%)
# 11:44:39 -   level: 3 / 66,118 (0.0%)
# 11:44:39 -   level_count: 3 / 66,118 (0.0%)
# 11:44:39 -   levels: 2 / 66,118 (0.0%)
# 11:44:39 -   license_type: 1 / 66,118 (0.0%)
# 11:44:39 -   licensed_content: 2 / 66,118 (0.0%)
# 11:44:39 -   licenses: 1 / 66,118 (0.0%)
# 11:44:39 -   licensor: 1 / 66,118 (0.0%)
# 11:44:39 -   limitations: 1 / 66,118 (0.0%)
# 11:44:39 -   limited_edition: 3 / 66,118 (0.0%)
# 11:44:39 -   limited_edition_content: 1 / 66,118 (0.0%)
# 11:44:39 -   limited_edition_contents: 1 / 66,118 (0.0%)
# 11:44:39 -   location: 1 / 66,118 (0.0%)
# 11:44:39 -   locations: 2 / 66,118 (0.0%)
# 11:44:39 -   locomotive_model: 1 / 66,118 (0.0%)
# 11:44:39 -   locomotives: 1 / 66,118 (0.0%)
# 11:44:39 -   loot_boxes: 0 / 66,118 (0.0%)
# 11:44:39 -   manual: 1 / 66,118 (0.0%)
# 11:44:39 -   manufacturer: 4 / 66,118 (0.0%)
# 11:44:39 -   manufacturer_country: 1 / 66,118 (0.0%)
# 11:44:39 -   manufacturer_model: 2 / 66,118 (0.0%)
# 11:44:39 -   manufacturer_number: 2 / 66,118 (0.0%)
# 11:44:39 -   manufacturer_part_numbers: 1 / 66,118 (0.0%)
# 11:44:39 -   material: 21 / 66,118 (0.0%)
# 11:44:39 -   materials: 2 / 66,118 (0.0%)
# 11:44:39 -   max_players: 1 / 66,118 (0.0%)
# 11:44:39 -   media_format: 3 / 66,118 (0.0%)
# 11:44:39 -   media_type: 2 / 66,118 (0.0%)
# 11:44:39 -   medium: 1 / 66,118 (0.0%)
# 11:44:39 -   memory_gb: 1 / 66,118 (0.0%)
# 11:44:39 -   metadata: 2 / 66,118 (0.0%)
# 11:44:39 -   min_players: 1 / 66,118 (0.0%)
# 11:44:39 -   min_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   min_system_requirements: 3 / 66,118 (0.0%)
# 11:44:39 -   minimum_graphics: 1 / 66,118 (0.0%)
# 11:44:39 -   minimum_hard_disk_space: 1 / 66,118 (0.0%)
# 11:44:39 -   minimum_processor: 2 / 66,118 (0.0%)
# 11:44:39 -   minimum_ram: 2 / 66,118 (0.0%)
# 11:44:39 -   minimum_requirements: 3 / 66,118 (0.0%)
# 11:44:39 -   minimum_sound: 1 / 66,118 (0.0%)
# 11:44:39 -   minimum_storage_gb: 1 / 66,118 (0.0%)
# 11:44:39 -   minimum_system_requirements: 15 / 66,118 (0.0%)
# 11:44:39 -   minimum_video_card: 1 / 66,118 (0.0%)
# 11:44:39 -   minor_league_teams: 1 / 66,118 (0.0%)
# 11:44:39 -   missions: 1 / 66,118 (0.0%)
# 11:44:39 -   model: 12 / 66,118 (0.0%)
# 11:44:39 -   model_name: 1 / 66,118 (0.0%)
# 11:44:39 -   model_number: 4 / 66,118 (0.0%)
# 11:44:39 -   model_numbers: 1 / 66,118 (0.0%)
# 11:44:39 -   model_year: 1 / 66,118 (0.0%)
# 11:44:39 -   modes: 5 / 66,118 (0.0%)
# 11:44:39 -   modification_required: 1 / 66,118 (0.0%)
# 11:44:39 -   monster_type: 2 / 66,118 (0.0%)
# 11:44:39 -   motion_controls: 0 / 66,118 (0.0%)
# 11:44:39 -   multiplayer: 30,613 / 66,118 (46.3%)
# 11:44:39 -   multiplayer_details: 1 / 66,118 (0.0%)
# 11:44:39 -   multiplayer_maps: 1 / 66,118 (0.0%)
# 11:44:39 -   multiplayer_player_count: 1 / 66,118 (0.0%)
# 11:44:39 -   music_genre: 1 / 66,118 (0.0%)
# 11:44:39 -   music_genres_featured: 1 / 66,118 (0.0%)
# 11:44:39 -   name: 7 / 66,118 (0.0%)
# 11:44:39 -   network_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   not_compatible_with: 3 / 66,118 (0.0%)
# 11:44:39 -   not_included: 1 / 66,118 (0.0%)
# 11:44:39 -   not_included_items: 1 / 66,118 (0.0%)
# 11:44:39 -   note: 1 / 66,118 (0.0%)
# 11:44:39 -   notes: 25 / 66,118 (0.0%)
# 11:44:39 -   number_of_missions: 1 / 66,118 (0.0%)
# 11:44:39 -   number_of_players: 0 / 66,118 (0.0%)
# 11:44:39 -   number_of_puzzles: 1 / 66,118 (0.0%)
# 11:44:39 -   objects_per_level: 3 / 66,118 (0.0%)
# 11:44:39 -   official_license: 1 / 66,118 (0.0%)
# 11:44:39 -   online_features: 1 / 66,118 (0.0%)
# 11:44:39 -   online_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   online_service_included: 1 / 66,118 (0.0%)
# 11:44:39 -   operating_system: 25 / 66,118 (0.0%)
# 11:44:39 -   operating_system_compatibility: 5 / 66,118 (0.0%)
# 11:44:39 -   operating_system_requirements: 2 / 66,118 (0.0%)
# 11:44:39 -   operating_systems: 4 / 66,118 (0.0%)
# 11:44:39 -   operator: 1 / 66,118 (0.0%)
# 11:44:39 -   operator_features: 1 / 66,118 (0.0%)
# 11:44:39 -   optical_drive: 1 / 66,118 (0.0%)
# 11:44:39 -   origin: 3 / 66,118 (0.0%)
# 11:44:39 -   original_console: 0 / 66,118 (0.0%)
# 11:44:39 -   original_game_title: 2 / 66,118 (0.0%)
# 11:44:39 -   original_manufacturer: 1 / 66,118 (0.0%)
# 11:44:39 -   original_platforms: 1 / 66,118 (0.0%)
# 11:44:39 -   original_price: 0 / 66,118 (0.0%)
# 11:44:39 -   original_product_name: 1 / 66,118 (0.0%)
# 11:44:39 -   original_release_included: 1 / 66,118 (0.0%)
# 11:44:39 -   original_release_series: 1 / 66,118 (0.0%)
# 11:44:39 -   original_release_year: 0 / 66,118 (0.0%)
# 11:44:39 -   os: 4 / 66,118 (0.0%)
# 11:44:39 -   os_compatibility: 9 / 66,118 (0.0%)
# 11:44:39 -   os_requirements: 2 / 66,118 (0.0%)
# 11:44:39 -   os_support: 1 / 66,118 (0.0%)
# 11:44:39 -   other_accessories_included: 1 / 66,118 (0.0%)
# 11:44:39 -   other_attributes: 16 / 66,118 (0.0%)
# 11:44:39 -   other_compatible_devices: 1 / 66,118 (0.0%)
# 11:44:39 -   other_content: 1 / 66,118 (0.0%)
# 11:44:39 -   other_details: 23 / 66,118 (0.0%)
# 11:44:39 -   other_features: 30 / 66,118 (0.0%)
# 11:44:39 -   other_games: 1 / 66,118 (0.0%)
# 11:44:39 -   other_games_mentioned: 1 / 66,118 (0.0%)
# 11:44:39 -   other_hardware_type: 6 / 66,118 (0.0%)
# 11:44:39 -   other_included_items: 3 / 66,118 (0.0%)
# 11:44:39 -   other_modes: 1 / 66,118 (0.0%)
# 11:44:39 -   other_platform_details: 1 / 66,118 (0.0%)
# 11:44:39 -   other_platforms: 1 / 66,118 (0.0%)
# 11:44:39 -   other_product_details: 2 / 66,118 (0.0%)
# 11:44:39 -   other_product_type: 1 / 66,118 (0.0%)
# 11:44:39 -   other_product_types: 1 / 66,118 (0.0%)
# 11:44:39 -   other_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   output_amperage: 1 / 66,118 (0.0%)
# 11:44:39 -   output_voltage: 1 / 66,118 (0.0%)
# 11:44:39 -   package_contents: 9 / 66,118 (0.0%)
# 11:44:39 -   package_quantity: 1 / 66,118 (0.0%)
# 11:44:39 -   packaging: 3 / 66,118 (0.0%)
# 11:44:39 -   parent_product: 1 / 66,118 (0.0%)
# 11:44:39 -   part_number: 5 / 66,118 (0.0%)
# 11:44:39 -   part_numbers: 2 / 66,118 (0.0%)
# 11:44:39 -   part_type: 3 / 66,118 (0.0%)
# 11:44:39 -   pegi_rating: 0 / 66,118 (0.0%)
# 11:44:39 -   perspective: 1 / 66,118 (0.0%)
# 11:44:39 -   physical_bonus_items: 1 / 66,118 (0.0%)
# 11:44:39 -   physical_digital: 1 / 66,118 (0.0%)
# 11:44:39 -   physical_edition: 4 / 66,118 (0.0%)
# 11:44:39 -   physical_edition_details: 1 / 66,118 (0.0%)
# 11:44:39 -   physical_format: 1 / 66,118 (0.0%)
# 11:44:39 -   physical_items_included: 1 / 66,118 (0.0%)
# 11:44:39 -   physical_media: 5 / 66,118 (0.0%)
# 11:44:39 -   physical_media_type: 0 / 66,118 (0.0%)
# 11:44:39 -   physical_product_details: 1 / 66,118 (0.0%)
# 11:44:39 -   platform: 64,329 / 66,118 (97.3%)
# 11:44:39 -   plating: 1 / 66,118 (0.0%)
# 11:44:39 -   play_modes: 1 / 66,118 (0.0%)
# 11:44:39 -   play_style: 2 / 66,118 (0.0%)
# 11:44:39 -   play_time_minutes: 1 / 66,118 (0.0%)
# 11:44:39 -   playable_characters: 2 / 66,118 (0.0%)
# 11:44:39 -   playable_characters_dlc: 1 / 66,118 (0.0%)
# 11:44:39 -   playable_status: 1 / 66,118 (0.0%)
# 11:44:39 -   player_count: 12 / 66,118 (0.0%)
# 11:44:39 -   playing_time: 1 / 66,118 (0.0%)
# 11:44:39 -   playtime_estimate: 1 / 66,118 (0.0%)
# 11:44:39 -   portability: 1 / 66,118 (0.0%)
# 11:44:39 -   ports: 2 / 66,118 (0.0%)
# 11:44:39 -   ports_by: 1 / 66,118 (0.0%)
# 11:44:39 -   power_input: 2 / 66,118 (0.0%)
# 11:44:39 -   power_output: 3 / 66,118 (0.0%)
# 11:44:39 -   power_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   power_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   power_supply_specifications: 1 / 66,118 (0.0%)
# 11:44:39 -   power_ups: 2 / 66,118 (0.0%)
# 11:44:39 -   preorder_bonus: 4 / 66,118 (0.0%)
# 11:44:39 -   prequel_to: 0 / 66,118 (0.0%)
# 11:44:39 -   price: 2 / 66,118 (0.0%)
# 11:44:39 -   processor: 7 / 66,118 (0.0%)
# 11:44:39 -   processor_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   processor_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   processor_speed: 3 / 66,118 (0.0%)
# 11:44:39 -   product_code: 1 / 66,118 (0.0%)
# 11:44:39 -   product_color: 1 / 66,118 (0.0%)
# 11:44:39 -   product_condition: 4 / 66,118 (0.0%)
# 11:44:39 -   product_connector_type: 1 / 66,118 (0.0%)
# 11:44:39 -   product_details: 5 / 66,118 (0.0%)
# 11:44:39 -   product_dimensions: 1 / 66,118 (0.0%)
# 11:44:39 -   product_function: 1 / 66,118 (0.0%)
# 11:44:39 -   product_length: 1 / 66,118 (0.0%)
# 11:44:39 -   product_material: 1 / 66,118 (0.0%)
# 11:44:39 -   product_name: 12 / 66,118 (0.0%)
# 11:44:39 -   product_origin: 1 / 66,118 (0.0%)
# 11:44:39 -   product_subtype: 3 / 66,118 (0.0%)
# 11:44:39 -   product_type: 66,117 / 66,118 (100.0%)
# 11:44:39 -   product_type_specific: 1 / 66,118 (0.0%)
# 11:44:39 -   protagonist: 1 / 66,118 (0.0%)
# 11:44:39 -   protection: 1 / 66,118 (0.0%)
# 11:44:39 -   protection_features: 1 / 66,118 (0.0%)
# 11:44:39 -   protection_type: 1 / 66,118 (0.0%)
# 11:44:39 -   publisher: 39 / 66,118 (0.1%)
# 11:44:39 -   publisher_url: 0 / 66,118 (0.0%)
# 11:44:39 -   publishers: 2 / 66,118 (0.0%)
# 11:44:39 -   puzzle_types: 1 / 66,118 (0.0%)
# 11:44:39 -   quantity: 3 / 66,118 (0.0%)
# 11:44:39 -   quantity_of_items: 1 / 66,118 (0.0%)
# 11:44:39 -   ram: 6 / 66,118 (0.0%)
# 11:44:39 -   ram_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   ram_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   rarity: 4 / 66,118 (0.0%)
# 11:44:39 -   rating: 22 / 66,118 (0.0%)
# 11:44:39 -   ratings: 0 / 66,118 (0.0%)
# 11:44:39 -   read_speed_mbps: 1 / 66,118 (0.0%)
# 11:44:39 -   recommended_system_requirements: 8 / 66,118 (0.0%)
# 11:44:39 -   refresh_rate_hz: 1 / 66,118 (0.0%)
# 11:44:39 -   refurbished: 1 / 66,118 (0.0%)
# 11:44:39 -   region: 10 / 66,118 (0.0%)
# 11:44:39 -   region_compatibility: 3 / 66,118 (0.0%)
# 11:44:39 -   region_free: 1 / 66,118 (0.0%)
# 11:44:39 -   region_lock: 7 / 66,118 (0.0%)
# 11:44:39 -   region_lock_info: 1 / 66,118 (0.0%)
# 11:44:39 -   regional_availability: 0 / 66,118 (0.0%)
# 11:44:39 -   regions: 0 / 66,118 (0.0%)
# 11:44:39 -   related_controllers: 1 / 66,118 (0.0%)
# 11:44:39 -   release_date: 17 / 66,118 (0.0%)
# 11:44:39 -   release_decade: 1 / 66,118 (0.0%)
# 11:44:39 -   release_details: 3 / 66,118 (0.0%)
# 11:44:39 -   release_format: 1 / 66,118 (0.0%)
# 11:44:39 -   release_region: 1 / 66,118 (0.0%)
# 11:44:39 -   release_status: 1 / 66,118 (0.0%)
# 11:44:39 -   release_title: 2 / 66,118 (0.0%)
# 11:44:39 -   release_type: 1 / 66,118 (0.0%)
# 11:44:39 -   release_year: 59 / 66,118 (0.1%)
# 11:44:39 -   release_year_range: 1 / 66,118 (0.0%)
# 11:44:39 -   remastered_or_remake: 1 / 66,118 (0.0%)
# 11:44:39 -   remastered_platforms: 1 / 66,118 (0.0%)
# 11:44:39 -   remastered_release_year: 0 / 66,118 (0.0%)
# 11:44:39 -   replacement_for: 1 / 66,118 (0.0%)
# 11:44:39 -   replacement_part_number: 1 / 66,118 (0.0%)
# 11:44:39 -   replacement_part_numbers: 1 / 66,118 (0.0%)
# 11:44:39 -   replacement_part_type: 1 / 66,118 (0.0%)
# 11:44:39 -   replacement_parts: 2 / 66,118 (0.0%)
# 11:44:39 -   required_game: 1 / 66,118 (0.0%)
# 11:44:39 -   requirements: 10 / 66,118 (0.0%)
# 11:44:39 -   requirements_notes: 1 / 66,118 (0.0%)
# 11:44:39 -   requires_controller: 1 / 66,118 (0.0%)
# 11:44:39 -   requires_internet: 0 / 66,118 (0.0%)
# 11:44:39 -   requires_steam_client: 1 / 66,118 (0.0%)
# 11:44:39 -   resolution: 3 / 66,118 (0.0%)
# 11:44:39 -   resolution_note: 1 / 66,118 (0.0%)
# 11:44:39 -   resolution_support: 2 / 66,118 (0.0%)
# 11:44:39 -   retailer: 0 / 66,118 (0.0%)
# 11:44:39 -   return_policy: 1 / 66,118 (0.0%)
# 11:44:39 -   route: 1 / 66,118 (0.0%)
# 11:44:39 -   route_details: 1 / 66,118 (0.0%)
# 11:44:39 -   sale_price: 0 / 66,118 (0.0%)
# 11:44:39 -   scent_profiles: 1 / 66,118 (0.0%)
# 11:44:39 -   screen_protector_type: 1 / 66,118 (0.0%)
# 11:44:39 -   screen_resolution: 2 / 66,118 (0.0%)
# 11:44:39 -   screen_size: 4 / 66,118 (0.0%)
# 11:44:39 -   screen_size_inches: 1 / 66,118 (0.0%)
# 11:44:39 -   secondary_hardware_type: 1 / 66,118 (0.0%)
# 11:44:39 -   sequel_to: 1 / 66,118 (0.0%)
# 11:44:39 -   series: 1 / 66,118 (0.0%)
# 11:44:39 -   series_edition: 1 / 66,118 (0.0%)
# 11:44:39 -   service_recreation: 1 / 66,118 (0.0%)
# 11:44:39 -   set: 3 / 66,118 (0.0%)
# 11:44:39 -   set_includes: 1 / 66,118 (0.0%)
# 11:44:39 -   setting: 11 / 66,118 (0.0%)
# 11:44:39 -   settings: 1 / 66,118 (0.0%)
# 11:44:39 -   size: 0 / 66,118 (0.0%)
# 11:44:39 -   skills_covered: 1 / 66,118 (0.0%)
# 11:44:39 -   skin_type: 4 / 66,118 (0.0%)
# 11:44:39 -   sku: 2 / 66,118 (0.0%)
# 11:44:39 -   slot_machines: 1 / 66,118 (0.0%)
# 11:44:39 -   slot_types: 1 / 66,118 (0.0%)
# 11:44:39 -   software_developer: 1 / 66,118 (0.0%)
# 11:44:39 -   software_edition: 1 / 66,118 (0.0%)
# 11:44:39 -   software_included: 3 / 66,118 (0.0%)
# 11:44:39 -   software_publisher: 1 / 66,118 (0.0%)
# 11:44:39 -   software_type: 3 / 66,118 (0.0%)
# 11:44:39 -   song_count: 1 / 66,118 (0.0%)
# 11:44:39 -   song_list_artists: 1 / 66,118 (0.0%)
# 11:44:39 -   songs: 1 / 66,118 (0.0%)
# 11:44:39 -   songs_included: 1 / 66,118 (0.0%)
# 11:44:39 -   sound: 1 / 66,118 (0.0%)
# 11:44:39 -   sound_card: 1 / 66,118 (0.0%)
# 11:44:39 -   sound_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   special_edition: 3 / 66,118 (0.0%)
# 11:44:39 -   special_features: 6 / 66,118 (0.0%)
# 11:44:39 -   specific_compatibility: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_details: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_device: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_device_compatibility: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_features: 2 / 66,118 (0.0%)
# 11:44:39 -   specific_hardware_details: 3 / 66,118 (0.0%)
# 11:44:39 -   specific_hardware_included: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_hardware_model: 4 / 66,118 (0.0%)
# 11:44:39 -   specific_hardware_type: 3 / 66,118 (0.0%)
# 11:44:39 -   specific_machines: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_model: 6 / 66,118 (0.0%)
# 11:44:39 -   specific_model_variant: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_models: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_product_name: 4 / 66,118 (0.0%)
# 11:44:39 -   specific_product_type: 4 / 66,118 (0.0%)
# 11:44:39 -   specific_type: 1 / 66,118 (0.0%)
# 11:44:39 -   specific_use: 1 / 66,118 (0.0%)
# 11:44:39 -   specifications: 7 / 66,118 (0.0%)
# 11:44:39 -   speed_class: 2 / 66,118 (0.0%)
# 11:44:39 -   storage: 6 / 66,118 (0.0%)
# 11:44:39 -   storage_capacity: 20 / 66,118 (0.0%)
# 11:44:39 -   storage_capacity_gb: 11 / 66,118 (0.0%)
# 11:44:39 -   storage_gb: 1 / 66,118 (0.0%)
# 11:44:39 -   storage_included: 2 / 66,118 (0.0%)
# 11:44:39 -   storage_required: 0 / 66,118 (0.0%)
# 11:44:39 -   storage_required_gb: 0 / 66,118 (0.0%)
# 11:44:39 -   storage_requirement: 1 / 66,118 (0.0%)
# 11:44:39 -   storage_requirement_gb: 1 / 66,118 (0.0%)
# 11:44:39 -   storage_requirements: 0 / 66,118 (0.0%)
# 11:44:39 -   storage_size_gb: 1 / 66,118 (0.0%)
# 11:44:39 -   store_currency: 1 / 66,118 (0.0%)
# 11:44:39 -   store_page: 0 / 66,118 (0.0%)
# 11:44:39 -   story_elements: 2 / 66,118 (0.0%)
# 11:44:39 -   studio: 1 / 66,118 (0.0%)
# 11:44:39 -   stylus: 1 / 66,118 (0.0%)
# 11:44:39 -   sub_brand: 6 / 66,118 (0.0%)
# 11:44:39 -   sub_category: 5 / 66,118 (0.0%)
# 11:44:39 -   sub_features: 1 / 66,118 (0.0%)
# 11:44:39 -   sub_franchise: 36 / 66,118 (0.1%)
# 11:44:39 -   sub_franchises: 3 / 66,118 (0.0%)
# 11:44:39 -   sub_games: 1 / 66,118 (0.0%)
# 11:44:39 -   sub_genre: 25 / 66,118 (0.0%)
# 11:44:39 -   sub_genre_details: 1 / 66,118 (0.0%)
# 11:44:39 -   sub_hardware_type: 2 / 66,118 (0.0%)
# 11:44:39 -   sub_product_type: 7 / 66,118 (0.0%)
# 11:44:39 -   sub_product_types: 2 / 66,118 (0.0%)
# 11:44:39 -   sub_products: 4 / 66,118 (0.0%)
# 11:44:39 -   sub_type: 15 / 66,118 (0.0%)
# 11:44:39 -   subfranchise: 2 / 66,118 (0.0%)
# 11:44:39 -   subgenre: 23 / 66,118 (0.0%)
# 11:44:39 -   subgenres: 4 / 66,118 (0.0%)
# 11:44:39 -   subscription_included: 1 / 66,118 (0.0%)
# 11:44:39 -   subtitle_language: 1 / 66,118 (0.0%)
# 11:44:39 -   subtitle_languages: 1 / 66,118 (0.0%)
# 11:44:39 -   subtitles: 0 / 66,118 (0.0%)
# 11:44:39 -   supported_features: 2 / 66,118 (0.0%)
# 11:44:39 -   supported_video_cards: 1 / 66,118 (0.0%)
# 11:44:39 -   system_requirements: 129 / 66,118 (0.2%)
# 11:44:39 -   table_details: 1 / 66,118 (0.0%)
# 11:44:39 -   tags: 7 / 66,118 (0.0%)
# 11:44:39 -   target_age: 1 / 66,118 (0.0%)
# 11:44:39 -   target_audience: 3 / 66,118 (0.0%)
# 11:44:39 -   team: 4 / 66,118 (0.0%)
# 11:44:39 -   technical_details: 1 / 66,118 (0.0%)
# 11:44:39 -   technical_features: 1 / 66,118 (0.0%)
# 11:44:39 -   technical_specifications: 2 / 66,118 (0.0%)
# 11:44:39 -   technical_specs: 1 / 66,118 (0.0%)
# 11:44:39 -   tested: 1 / 66,118 (0.0%)
# 11:44:39 -   theme: 2 / 66,118 (0.0%)
# 11:44:39 -   themed_content: 1 / 66,118 (0.0%)
# 11:44:39 -   themes: 23 / 66,118 (0.0%)
# 11:44:39 -   time_period: 1 / 66,118 (0.0%)
# 11:44:39 -   title: 332 / 66,118 (0.5%)
# 11:44:39 -   title_addition: 1 / 66,118 (0.0%)
# 11:44:39 -   title_addon: 1 / 66,118 (0.0%)
# 11:44:39 -   title_analysis: 2 / 66,118 (0.0%)
# 11:44:39 -   title_details: 7 / 66,118 (0.0%)
# 11:44:39 -   title_extra: 2 / 66,118 (0.0%)
# 11:44:39 -   title_full: 1 / 66,118 (0.0%)
# 11:44:39 -   title_keywords: 1 / 66,118 (0.0%)
# 11:44:39 -   tool_types: 1 / 66,118 (0.0%)
# 11:44:39 -   tools: 1 / 66,118 (0.0%)
# 11:44:39 -   total_achievements: 1 / 66,118 (0.0%)
# 11:44:39 -   total_characters_with_variations: 1 / 66,118 (0.0%)
# 11:44:39 -   total_hidden_objects: 1 / 66,118 (0.0%)
# 11:44:39 -   total_objects: 2 / 66,118 (0.0%)
# 11:44:39 -   touch_functionality: 1 / 66,118 (0.0%)
# 11:44:39 -   touchscreen_support: 1 / 66,118 (0.0%)
# 11:44:39 -   track_types: 1 / 66,118 (0.0%)
# 11:44:39 -   tracking_support: 1 / 66,118 (0.0%)
# 11:44:39 -   tracks: 1 / 66,118 (0.0%)
# 11:44:39 -   type: 1 / 66,118 (0.0%)
# 11:44:39 -   units: 1 / 66,118 (0.0%)
# 11:44:39 -   upc: 3 / 66,118 (0.0%)
# 11:44:39 -   upgrade_info: 1 / 66,118 (0.0%)
# 11:44:39 -   upgrade_path: 1 / 66,118 (0.0%)
# 11:44:39 -   user_reviews: 0 / 66,118 (0.0%)
# 11:44:39 -   value: 1 / 66,118 (0.0%)
# 11:44:39 -   value_proposition: 1 / 66,118 (0.0%)
# 11:44:39 -   vehicle_types: 1 / 66,118 (0.0%)
# 11:44:39 -   vehicles: 4 / 66,118 (0.0%)
# 11:44:39 -   version: 1 / 66,118 (0.0%)
# 11:44:39 -   video_card: 4 / 66,118 (0.0%)
# 11:44:39 -   video_card_requirements: 1 / 66,118 (0.0%)
# 11:44:39 -   video_features: 0 / 66,118 (0.0%)
# 11:44:39 -   video_formats: 1 / 66,118 (0.0%)
# 11:44:39 -   virtual_currency: 1 / 66,118 (0.0%)
# 11:44:39 -   virtual_currency_amount: 1 / 66,118 (0.0%)
# 11:44:39 -   virtual_reality: 1 / 66,118 (0.0%)
# 11:44:39 -   virtual_reality_compatible: 1 / 66,118 (0.0%)
# 11:44:39 -   visual_features: 1 / 66,118 (0.0%)
# 11:44:39 -   voltage: 2 / 66,118 (0.0%)
# 11:44:39 -   voltage_V: 1 / 66,118 (0.0%)
# 11:44:39 -   voltage_v: 2 / 66,118 (0.0%)
# 11:44:39 -   vr_compatibility: 1 / 66,118 (0.0%)
# 11:44:39 -   vr_required: 1 / 66,118 (0.0%)
# 11:44:39 -   vr_support: 1 / 66,118 (0.0%)
# 11:44:39 -   wager_lines: 1 / 66,118 (0.0%)
# 11:44:39 -   warranty: 23 / 66,118 (0.0%)
# 11:44:39 -   warranty_and_returns: 1 / 66,118 (0.0%)
# 11:44:39 -   warranty_impact: 1 / 66,118 (0.0%)
# 11:44:39 -   warranty_years: 1 / 66,118 (0.0%)
# 11:44:39 -   weapons: 1 / 66,118 (0.0%)
# 11:44:39 -   weight: 7 / 66,118 (0.0%)
# 11:44:39 -   weight_grams: 1 / 66,118 (0.0%)
# 11:44:39 -   wire_gauge: 1 / 66,118 (0.0%)
# 11:44:39 -   word_count: 1 / 66,118 (0.0%)
# 11:44:39 -   write_speed_mbps: 1 / 66,118 (0.0%)
# 11:44:39 -   year: 6 / 66,118 (0.0%)
# 11:44:39 -   year_of_release: 2 / 66,118 (0.0%)
# 11:44:39 -
# Product type distribution:
# 11:44:39 -   Accessory: 28,063
# 11:44:39 -   Game: 25,901
# 11:44:39 -   Hardware: 5,875
# 11:44:39 -   Bundle: 3,946
# 11:44:39 -   DLC: 1,888
# 11:44:39 -   Software: 81
# 11:44:39 -   null: 74
# 11:44:39 -   DLC|Bundle: 70
# 11:44:39 -   Book: 68
# 11:44:39 -   Accessory|Bundle: 25
# 11:44:39 -
# Platform distribution (flattened):
# 11:44:39 -   PC: 22,242
# 11:44:39 -   PS4: 7,950
# 11:44:39 -   Nintendo Switch: 6,103
# 11:44:39 -   Xbox One: 5,939
# 11:44:39 -   Xbox 360: 3,886
# 11:44:39 -   PS3: 3,185
# 11:44:39 -   Wii: 2,281
# 11:44:39 -   Nintendo DS: 2,030
# 11:44:39 -   PS5: 1,987
# 11:44:39 -   Mac: 1,932
# 11:44:39 -   Nintendo 3DS: 1,408
# 11:44:39 -   PS2: 1,118
# 11:44:39 -   PlayStation 2: 1,118
# 11:44:39 -   Xbox Series X: 1,016
# 11:44:39 -   Wii U: 1,010
# 11:44:39 -
# Genre distribution (flattened):
# 11:44:39 -   Action: 10,970
# 11:44:39 -   Adventure: 6,885
# 11:44:39 -   Simulation: 5,624
# 11:44:39 -   Puzzle: 5,398
# 11:44:39 -   Strategy: 4,275
# 11:44:39 -   Sports: 3,591
# 11:44:39 -   RPG: 3,099
# 11:44:39 -   Racing: 2,610
# 11:44:39 -   Open World: 2,092
# 11:44:39 -   Platformer: 1,998
# 11:44:39 -   Shooter: 1,717
# 11:44:39 -   Hidden Object: 1,564
# 11:44:39 -   Arcade: 1,258
# 11:44:39 -   Fighting: 1,151
# 11:44:39 -   Action RPG: 1,083
# 11:44:39 -   Horror: 1,051
# 11:44:39 -   Mystery: 1,017
# 11:44:39 -   Action-Adventure: 975
# 11:44:39 -   Educational: 973
# 11:44:39 -   Sandbox: 967
# 11:44:39 -
# Multiplayer mode distribution:
# 11:44:39 -   Single-player: 22,949
# 11:44:39 -   Online Multiplayer: 6,860
# 11:44:39 -   Local Co-op: 4,329
# 11:44:39 -   PvP: 2,383
# 11:44:39 -   Couch Co-op: 1,489
# 11:44:39 -   PvE: 723
# 11:44:39 -   MMORPG: 307
# 11:44:39 -   Local Multiplayer: 287
# 11:44:39 -   Co-op: 282
# 11:44:39 -   MMO: 205

# %% [markdown]
# ## 6. Save Metadata as DataFrame

# %%
# Convert metadata to DataFrame format - handling mixed types properly
if checkpoint_file.exists() and len(metadata_records) > 0:
    # Filter out error records
    clean_records = [
        record for record in metadata_records if not record.get("extraction_failed") and not record.get("error")
    ]

    # Define which fields should be lists
    list_fields = ["platform", "genre", "compatibility"]
    EXPECTED_FIELDS = {"product_type", "platform", "genre", "hardware_type", "brand", "multiplayer", "franchise"}
    # Normalize records to ensure consistent types
    normalized_records = []
    for record in clean_records:
        filtered_record = {"parent_asin": record.get("parent_asin")}
        for key in EXPECTED_FIELDS:
            if key in record:
                filtered_record[key] = record[key]
        normalized = {}
        for key, value in filtered_record.items():
            if key in list_fields:
                # Ensure list fields are always lists
                if value is None:
                    normalized[key] = None
                elif isinstance(value, list):
                    normalized[key] = value
                else:
                    normalized[key] = [value]  # Convert single values to list
            else:
                # For non-list fields, ensure they're not lists
                if isinstance(value, list):
                    # If a non-list field has a list value, join it
                    try:
                        normalized[key] = ", ".join(value) if value else None
                    except Exception as e:
                        logger.warning(f"Error joining list for key: {key}, value: {value}")
                        normalized[key] = None
                else:
                    normalized[key] = value
        normalized_records.append(normalized)

    # Create DataFrame with normalized records
    metadata_df = pl.DataFrame(normalized_records)

    # Save as Parquet file (Parquet natively supports nested data types like lists)
    metadata_parquet_path = DATA_DIR / "output" / f"{CATEGORY}_metadata_extracted.parquet"
    metadata_df.write_parquet(metadata_parquet_path)
    logger.info(f"Saved metadata DataFrame with {len(metadata_df):,} records to {metadata_parquet_path}")

    # Display DataFrame info
    logger.info(f"\nDataFrame shape: {metadata_df.shape}")
    logger.info(f"Columns: {metadata_df.columns}")

    # Show sample of the DataFrame
    logger.info("\nSample of metadata DataFrame:")
    display(metadata_df.head(5))

    # Show data types (lists will show as List[Utf8])
    logger.info("\nColumn data types:")
    for col in metadata_df.columns:
        dtype = metadata_df[col].dtype
        null_count = metadata_df[col].null_count()
        non_null = len(metadata_df) - null_count
        logger.info(f"  {col}: {dtype} (non-null: {non_null}/{len(metadata_df)})")

    # Demonstrate how to work with array columns
    logger.info("\n--- Working with Array Columns ---")

    # Example 1: Explode genre array to see all genres
    if "genre" in metadata_df.columns:
        genres_exploded = (
            metadata_df.select(["parent_asin", "genre"]).filter(pl.col("genre").is_not_null()).explode("genre")
        )
        genre_counts = genres_exploded.group_by("genre").agg(pl.count().alias("count")).sort("count", descending=True)
        logger.info("\nExample 1 - Genre distribution (top 10):")
        display(genre_counts.head(10))

    # Example 2: Filter items by specific genre
    if "genre" in metadata_df.columns:
        # Find games with RPG genre
        rpg_games = metadata_df.filter(
            pl.col("genre").list.contains("RPG")
            | pl.col("genre").list.contains("JRPG")
            | pl.col("genre").list.contains("Action RPG")
        )
        logger.info(f"\nExample 2 - Games with RPG-related genres: {len(rpg_games)}")
        if len(rpg_games) > 0:
            display(rpg_games.select(["parent_asin", "product_type", "genre"]).head(3))

    # Example 3: Platform distribution
    if "platform" in metadata_df.columns:
        platforms_exploded = (
            metadata_df.select(["parent_asin", "platform"]).filter(pl.col("platform").is_not_null()).explode("platform")
        )
        platform_counts = (
            platforms_exploded.group_by("platform").agg(pl.count().alias("count")).sort("count", descending=True)
        )
        logger.info("\nExample 3 - Platform distribution:")
        display(platform_counts)

    # Example 4: Finding games by multiple criteria
    if "genre" in metadata_df.columns and "platform" in metadata_df.columns:
        # Find action games on PC
        action_pc_games = metadata_df.filter(
            (pl.col("product_type") == "Game")
            & (pl.col("platform").list.contains("PC"))
            & (pl.col("genre").list.contains("Action") | pl.col("genre").list.contains("Shooter"))
        )
        logger.info(f"\nExample 4 - Action/Shooter games on PC: {len(action_pc_games)}")
        if len(action_pc_games) > 0:
            display(action_pc_games.select(["parent_asin", "genre", "platform"]).head(3))

else:
    logger.warning("No metadata records to convert to DataFrame")
# Out:
# 14:19:19 - Saved metadata DataFrame with 66,117 records to /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_metadata_extracted.parquet
# 14:19:19 -
# DataFrame shape: (66117, 8)
# 14:19:19 - Columns: ['parent_asin', 'genre', 'brand', 'product_type', 'platform', 'hardware_type', 'franchise', 'multiplayer']
# 14:19:19 -
# Sample of metadata DataFrame:
# shape: (5, 8)
# ┌────────────┬────────────┬───────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ parent_asi ┆ genre      ┆ brand     ┆ product_ty ┆ platform  ┆ hardware_ ┆ franchise ┆ multiplay │
# │ n          ┆ ---        ┆ ---       ┆ pe         ┆ ---       ┆ type      ┆ ---       ┆ er        │
# │ ---        ┆ list[str]  ┆ str       ┆ ---        ┆ list[str] ┆ ---       ┆ str       ┆ ---       │
# │ str        ┆            ┆           ┆ str        ┆           ┆ str       ┆           ┆ str       │
# ╞════════════╪════════════╪═══════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ B001EDF55W ┆ ["Simulati ┆ null      ┆ Game       ┆ ["PC"]    ┆ null      ┆ null      ┆ Single-pl │
# │            ┆ on",       ┆           ┆            ┆           ┆           ┆           ┆ ayer      │
# │            ┆ "Racing",  ┆           ┆            ┆           ┆           ┆           ┆           │
# │            ┆ "Spor…     ┆           ┆            ┆           ┆           ┆           ┆           │
# │ B08S7MCMM2 ┆ null       ┆ OLOPE     ┆ Accessory  ┆ ["PS5"]   ┆ Controlle ┆ null      ┆ null      │
# │            ┆            ┆           ┆            ┆           ┆ r         ┆           ┆           │
# │ B001ELJP4G ┆ ["Racing"] ┆ dreamGEAR ┆ Accessory  ┆ ["Wii"]   ┆ Controlle ┆ null      ┆ null      │
# │            ┆            ┆           ┆            ┆           ┆ r         ┆           ┆           │
# │ B0171WA496 ┆ null       ┆ GameXcel  ┆ Accessory  ┆ ["Xbox    ┆ Skin      ┆ null      ┆ null      │
# │            ┆            ┆           ┆            ┆ One"]     ┆           ┆           ┆           │
# │ B07HRWKLXX ┆ null       ┆ Obeka     ┆ Accessory  ┆ ["Xbox    ┆ Controlle ┆ Xbox One  ┆ null      │
# │            ┆            ┆           ┆            ┆ One"]     ┆ r Skin    ┆ Elite Con ┆           │
# │            ┆            ┆           ┆            ┆           ┆           ┆ troller   ┆           │
# └────────────┴────────────┴───────────┴────────────┴───────────┴───────────┴───────────┴───────────┘
# 14:19:19 -
# Column data types:
# 14:19:19 -   parent_asin: String (non-null: 66117/66117)
# 14:19:19 -   genre: List(String) (non-null: 32970/66117)
# 14:19:19 -   brand: String (non-null: 51285/66117)
# 14:19:19 -   product_type: String (non-null: 66117/66117)
# 14:19:19 -   platform: List(String) (non-null: 64329/66117)
# 14:19:19 -   hardware_type: String (non-null: 34145/66117)
# 14:19:19 -   franchise: String (non-null: 35863/66117)
# 14:19:19 -   multiplayer: String (non-null: 30613/66117)
# 14:19:19 -
# --- Working with Array Columns ---
# 14:19:19 -
# Example 1 - Genre distribution (top 10):
# /tmp/ipykernel_316862/2337049762.py:73: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   genre_counts = genres_exploded.group_by("genre").agg(pl.count().alias("count")).sort("count", descending=True)
# shape: (10, 2)
# ┌────────────┬───────┐
# │ genre      ┆ count │
# │ ---        ┆ ---   │
# │ str        ┆ u32   │
# ╞════════════╪═══════╡
# │ Action     ┆ 10970 │
# │ Adventure  ┆ 6885  │
# │ Simulation ┆ 5624  │
# │ Puzzle     ┆ 5398  │
# │ Strategy   ┆ 4275  │
# │ Sports     ┆ 3591  │
# │ RPG        ┆ 3099  │
# │ Racing     ┆ 2610  │
# │ Open World ┆ 2092  │
# │ Platformer ┆ 1998  │
# └────────────┴───────┘
# 14:19:19 -
# Example 2 - Games with RPG-related genres: 3785
# shape: (3, 3)
# ┌─────────────┬──────────────┬─────────────────────────────────┐
# │ parent_asin ┆ product_type ┆ genre                           │
# │ ---         ┆ ---          ┆ ---                             │
# │ str         ┆ str          ┆ list[str]                       │
# ╞═════════════╪══════════════╪═════════════════════════════════╡
# │ B072282HLF  ┆ Game         ┆ ["Fantasy", "Adventure", … "Op… │
# │ B001EYURIQ  ┆ Game         ┆ ["RPG", "Fantasy", "Action RPG… │
# │ B07T6V433D  ┆ Bundle       ┆ ["Action", "Adventure", … "Mys… │
# └─────────────┴──────────────┴─────────────────────────────────┘
# 14:19:19 -
# Example 3 - Platform distribution:
# /tmp/ipykernel_316862/2337049762.py:95: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   platforms_exploded.group_by("platform").agg(pl.count().alias("count")).sort("count", descending=True)
# shape: (1_202, 2)
# ┌────────────────────────────┬───────┐
# │ platform                   ┆ count │
# │ ---                        ┆ ---   │
# │ str                        ┆ u32   │
# ╞════════════════════════════╪═══════╡
# │ PC                         ┆ 22242 │
# │ PS4                        ┆ 7950  │
# │ Nintendo Switch            ┆ 6103  │
# │ Xbox One                   ┆ 5939  │
# │ Xbox 360                   ┆ 3886  │
# │ …                          ┆ …     │
# │ UMD                        ┆ 1     │
# │ PC (Windows)               ┆ 1     │
# │ GameCube (via adapter)     ┆ 1     │
# │ Genesis Mini               ┆ 1     │
# │ NES (third-party consoles) ┆ 1     │
# └────────────────────────────┴───────┘
# 14:19:19 -
# Example 4 - Action/Shooter games on PC: 2110
# shape: (3, 3)
# ┌─────────────┬─────────────────────────────────┬───────────┐
# │ parent_asin ┆ genre                           ┆ platform  │
# │ ---         ┆ ---                             ┆ ---       │
# │ str         ┆ list[str]                       ┆ list[str] │
# ╞═════════════╪═════════════════════════════════╪═══════════╡
# │ B00CX6FZCC  ┆ ["Action", "Third-person Shoot… ┆ ["PC"]    │
# │ B000BU0FUY  ┆ ["Action", "3D Adventure"]      ┆ ["PC"]    │
# │ B001K7HV18  ┆ ["Platformer", "Action", "Arca… ┆ ["PC"]    │
# └─────────────┴─────────────────────────────────┴───────────┘

# %%
metadata_df.filter(pl.col("multiplayer").is_not_null())
# Out:
# shape: (30_613, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ parent_asi ┆ genre      ┆ brand      ┆ product_t ┆ platform  ┆ hardware_ ┆ franchise ┆ multiplay │
# │ n          ┆ ---        ┆ ---        ┆ ype       ┆ ---       ┆ type      ┆ ---       ┆ er        │
# │ ---        ┆ list[str]  ┆ str        ┆ ---       ┆ list[str] ┆ ---       ┆ str       ┆ ---       │
# │ str        ┆            ┆            ┆ str       ┆           ┆ str       ┆           ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ B001EDF55W ┆ ["Simulati ┆ null       ┆ Game      ┆ ["PC"]    ┆ null      ┆ null      ┆ Single-pl │
# │            ┆ on",       ┆            ┆           ┆           ┆           ┆           ┆ ayer      │
# │            ┆ "Racing",  ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ "Spor…     ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B00EPC3PY2 ┆ ["Action", ┆ Bandai     ┆ Game      ┆ ["PS3"]   ┆ null      ┆ One Piece ┆ Single-pl │
# │            ┆ "Musou"]   ┆ Namco      ┆           ┆           ┆           ┆           ┆ ayer      │
# │ B00CX6FZCC ┆ ["Action", ┆ null       ┆ Game      ┆ ["PC"]    ┆ null      ┆ Deadpool  ┆ Single-pl │
# │            ┆ "Third-per ┆            ┆           ┆           ┆           ┆           ┆ ayer      │
# │            ┆ son Shoot… ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B004H0LQO8 ┆ ["Puzzle", ┆ Fishdom    ┆ Bundle    ┆ ["PC"]    ┆ null      ┆ Fishdom   ┆ Single-pl │
# │            ┆ "Simulatio ┆            ┆           ┆           ┆           ┆           ┆ ayer      │
# │            ┆ n"]        ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B002BSA1HQ ┆ ["Rail     ┆ Nerf       ┆ Bundle    ┆ ["Wii"]   ┆ Controlle ┆ N-Strike  ┆ Local     │
# │            ┆ Shooter",  ┆            ┆           ┆           ┆ r         ┆ Elite     ┆ Co-op     │
# │            ┆ "Action"]  ┆            ┆           ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         ┆ …         │
# │ B075YGQ393 ┆ ["Action   ┆ Falcom     ┆ Game      ┆ ["PS      ┆ null      ┆ Ys        ┆ Single-pl │
# │            ┆ RPG", "Adv ┆            ┆           ┆ Vita"]    ┆           ┆           ┆ ayer      │
# │            ┆ enture",   ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ "H…        ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B006QRNKOO ┆ ["Action-A ┆ Nintendo   ┆ Game      ┆ ["Wii"]   ┆ null      ┆ The       ┆ Single-pl │
# │            ┆ dventure", ┆            ┆           ┆           ┆           ┆ Legend of ┆ ayer      │
# │            ┆ "Action",… ┆            ┆           ┆           ┆           ┆ Zelda     ┆           │
# │ B00UW4BGLG ┆ ["Sports", ┆ R.B.I.     ┆ Game      ┆ ["PS4"]   ┆ null      ┆ R.B.I.    ┆ Single-pl │
# │            ┆ "Baseball" ┆ Baseball   ┆           ┆           ┆           ┆ Baseball  ┆ ayer,     │
# │            ┆ ]          ┆            ┆           ┆           ┆           ┆           ┆ Local     │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ Co-op,    │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ On…       │
# │ B001J2S0WI ┆ ["RPG",    ┆ ArenaNet   ┆ Bundle    ┆ ["PC"]    ┆ null      ┆ Guild     ┆ Online    │
# │            ┆ "MMORPG",  ┆            ┆           ┆           ┆           ┆ Wars      ┆ Multiplay │
# │            ┆ "Fantasy"] ┆            ┆           ┆           ┆           ┆           ┆ er,       │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ MMORPG,   │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ Pv…       │
# │ B081ZL8Q9Z ┆ ["Sandbox" ┆ Microsoft  ┆ Bundle    ┆ ["Xbox    ┆ Console   ┆ Minecraft ┆ Single-pl │
# │            ┆ , "Adventu ┆            ┆           ┆ One"]     ┆           ┆           ┆ ayer,     │
# │            ┆ re",       ┆            ┆           ┆           ┆           ┆           ┆ Online    │
# │            ┆ "Buil…     ┆            ┆           ┆           ┆           ┆           ┆ Multipla… │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
metadata_df.filter(pl.col("multiplayer").is_not_null())
# Out:
# shape: (30_613, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ parent_asi ┆ genre      ┆ brand      ┆ product_t ┆ platform  ┆ hardware_ ┆ franchise ┆ multiplay │
# │ n          ┆ ---        ┆ ---        ┆ ype       ┆ ---       ┆ type      ┆ ---       ┆ er        │
# │ ---        ┆ list[str]  ┆ str        ┆ ---       ┆ list[str] ┆ ---       ┆ str       ┆ ---       │
# │ str        ┆            ┆            ┆ str       ┆           ┆ str       ┆           ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ B001EDF55W ┆ ["Simulati ┆ null       ┆ Game      ┆ ["PC"]    ┆ null      ┆ null      ┆ Single-pl │
# │            ┆ on",       ┆            ┆           ┆           ┆           ┆           ┆ ayer      │
# │            ┆ "Racing",  ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ "Spor…     ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B00EPC3PY2 ┆ ["Action", ┆ Bandai     ┆ Game      ┆ ["PS3"]   ┆ null      ┆ One Piece ┆ Single-pl │
# │            ┆ "Musou"]   ┆ Namco      ┆           ┆           ┆           ┆           ┆ ayer      │
# │ B00CX6FZCC ┆ ["Action", ┆ null       ┆ Game      ┆ ["PC"]    ┆ null      ┆ Deadpool  ┆ Single-pl │
# │            ┆ "Third-per ┆            ┆           ┆           ┆           ┆           ┆ ayer      │
# │            ┆ son Shoot… ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B004H0LQO8 ┆ ["Puzzle", ┆ Fishdom    ┆ Bundle    ┆ ["PC"]    ┆ null      ┆ Fishdom   ┆ Single-pl │
# │            ┆ "Simulatio ┆            ┆           ┆           ┆           ┆           ┆ ayer      │
# │            ┆ n"]        ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B002BSA1HQ ┆ ["Rail     ┆ Nerf       ┆ Bundle    ┆ ["Wii"]   ┆ Controlle ┆ N-Strike  ┆ Local     │
# │            ┆ Shooter",  ┆            ┆           ┆           ┆ r         ┆ Elite     ┆ Co-op     │
# │            ┆ "Action"]  ┆            ┆           ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         ┆ …         │
# │ B075YGQ393 ┆ ["Action   ┆ Falcom     ┆ Game      ┆ ["PS      ┆ null      ┆ Ys        ┆ Single-pl │
# │            ┆ RPG", "Adv ┆            ┆           ┆ Vita"]    ┆           ┆           ┆ ayer      │
# │            ┆ enture",   ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ "H…        ┆            ┆           ┆           ┆           ┆           ┆           │
# │ B006QRNKOO ┆ ["Action-A ┆ Nintendo   ┆ Game      ┆ ["Wii"]   ┆ null      ┆ The       ┆ Single-pl │
# │            ┆ dventure", ┆            ┆           ┆           ┆           ┆ Legend of ┆ ayer      │
# │            ┆ "Action",… ┆            ┆           ┆           ┆           ┆ Zelda     ┆           │
# │ B00UW4BGLG ┆ ["Sports", ┆ R.B.I.     ┆ Game      ┆ ["PS4"]   ┆ null      ┆ R.B.I.    ┆ Single-pl │
# │            ┆ "Baseball" ┆ Baseball   ┆           ┆           ┆           ┆ Baseball  ┆ ayer,     │
# │            ┆ ]          ┆            ┆           ┆           ┆           ┆           ┆ Local     │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ Co-op,    │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ On…       │
# │ B001J2S0WI ┆ ["RPG",    ┆ ArenaNet   ┆ Bundle    ┆ ["PC"]    ┆ null      ┆ Guild     ┆ Online    │
# │            ┆ "MMORPG",  ┆            ┆           ┆           ┆           ┆ Wars      ┆ Multiplay │
# │            ┆ "Fantasy"] ┆            ┆           ┆           ┆           ┆           ┆ er,       │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ MMORPG,   │
# │            ┆            ┆            ┆           ┆           ┆           ┆           ┆ Pv…       │
# │ B081ZL8Q9Z ┆ ["Sandbox" ┆ Microsoft  ┆ Bundle    ┆ ["Xbox    ┆ Console   ┆ Minecraft ┆ Single-pl │
# │            ┆ , "Adventu ┆            ┆           ┆ One"]     ┆           ┆           ┆ ayer,     │
# │            ┆ re",       ┆            ┆           ┆           ┆           ┆           ┆ Online    │
# │            ┆ "Buil…     ┆            ┆           ┆           ┆           ┆           ┆ Multipla… │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘
