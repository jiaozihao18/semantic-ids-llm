# %% [markdown]
# # Clean Item Descriptions and Features

# %%
# CATEGORY = "Baby_Products"
CATEGORY = "Video_Games"

# Define sequence lengths
MIN_SEQUENCE_LENGTH = 3
MAX_SEQUENCE_LENGTH = 100  # Adjust as needed

# %%
import sys
from pathlib import Path

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = NOTEBOOK_DIR.parent
sys.path.append(str(PROJECT_ROOT))

# Data directory
DATA_DIR = Path(PROJECT_ROOT, "data")
DATA_DIR.mkdir(exist_ok=True)

# %%
import csv
import json
import logging
import os
import threading
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import Dict

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
from dotenv import load_dotenv
from google import genai
from IPython.display import display
from polars.exceptions import NoDataError
from tqdm.notebook import tqdm

from src.logger import setup_logger

# Set environment variables to reduce Google API verbosity
os.environ["GRPC_VERBOSITY"] = "ERROR"
os.environ["GLOG_minloglevel"] = "2"

logger = setup_logger("clean-items")
logging.getLogger("httpcore").setLevel(logging.WARNING)
logging.getLogger("httpx").setLevel(logging.WARNING)
logging.getLogger("google_genai").setLevel(logging.WARNING)

# %%
load_dotenv()
# Out:
# True

# %%
# API settings
MODEL = "gemini-2.5-flash-lite"
MAX_RETRIES: int = 5
RETRY_DELAY: float = 1.0  # Seconds
RATE_LIMIT_DELAY: float = 0.2  # Seconds between API calls
MAX_THREADS: int = 10

# Text processing settings
MAX_DESCRIPTION_LENGTH: int = 2000  # Truncate before sending to API
MAX_FEATURES_LENGTH: int = 1500
MIN_DESCRIPTION_LENGTH: int = 50  # Minimgemini_model: str = "gemini-2.0-flash-exp"um length to consider valid
MIN_FEATURES_LENGTH: int = 20

# %% [markdown]
# ## 2. Load Data and Initial Analysis

# %%
# Load the data
df = pl.read_parquet(DATA_DIR / "output" / f"{CATEGORY}_items.parquet")
logger.info(f"Loaded {len(df):,} items from {DATA_DIR / 'output' / f'{CATEGORY}_items.parquet'}")

# Display basic information
print(f"Total items: {len(df):,}")
print(f"Columns: {df.columns}")
display(df.head(3).select(["parent_asin", "title", "description_text", "features_text"]))
# Out:
# 21:55:32 - Loaded 66,133 items from /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_items.parquet
# Total items: 66,133
# Columns: ['parent_asin', 'title', 'description_text', 'features_text', 'main_category', 'categories_text', 'store', 'average_rating', 'rating_number', 'price', 'item_context']
# shape: (3, 4)
# ┌─────────────┬────────────────────────────┬───────────────────────────┬───────────────────────────┐
# │ parent_asin ┆ title                      ┆ description_text          ┆ features_text             │
# │ ---         ┆ ---                        ┆ ---                       ┆ ---                       │
# │ str         ┆ str                        ┆ str                       ┆ str                       │
# ╞═════════════╪════════════════════════════╪═══════════════════════════╪═══════════════════════════╡
# │ B000FH0MHO  ┆ Dash 8-300 Professional    ┆ The Dash 8-300            ┆ Features Dash 8-300 and   │
# │             ┆ Add-On                     ┆ Professional Ad…          ┆ 8-Q300…                   │
# │ B00Z9TLVK0  ┆ NBA 2K17 - Early Tip Off   ┆ Following the             ┆ The #1 rated NBA video    │
# │             ┆ Editi…                     ┆ record-breaking …         ┆ game si…                  │
# │ B002WH4ZJG  ┆ Thrustmaster Elite Fitness ┆ The Thrustmaster Motion   ┆ Includes (9) Total        │
# │             ┆ Pac…                       ┆ Plus E…                   ┆ Accessories…              │
# └─────────────┴────────────────────────────┴───────────────────────────┴───────────────────────────┘

# %%
# Analyze text quality issues
def analyze_text_quality(df: pl.DataFrame) -> Dict:
    """Analyze text quality issues in the dataset."""
    stats = {}

    # Length statistics
    desc_lengths = df["description_text"].str.len_chars()
    feat_lengths = df["features_text"].str.len_chars()

    stats["description"] = {
        "min_length": desc_lengths.min(),
        "max_length": desc_lengths.max(),
        "mean_length": desc_lengths.mean(),
        "median_length": desc_lengths.median(),
        "empty_count": (desc_lengths == 0).sum(),
        "truncated_count": df["description_text"].str.ends_with("...").sum(),
    }

    stats["features"] = {
        "min_length": feat_lengths.min(),
        "max_length": feat_lengths.max(),
        "mean_length": feat_lengths.mean(),
        "median_length": feat_lengths.median(),
        "empty_count": (feat_lengths == 0).sum(),
    }

    # Check for common issues
    stats["issues"] = {
        "html_entities": df.filter(pl.col("description_text").str.contains("&amp;|&lt;|&gt;|&nbsp;")).shape[0],
        "excessive_whitespace": df.filter(pl.col("description_text").str.contains(r"\s{3,}")).shape[0],
        "no_punctuation_features": df.filter(
            (pl.col("features_text").str.len_chars() > 0) & (~pl.col("features_text").str.contains(r"[.!?]"))
        ).shape[0],
    }

    return stats


initial_stats = analyze_text_quality(df)
logger.info("Initial Text Quality Analysis:")
logger.info(json.dumps(initial_stats, indent=2, default=str))
# Out:
# 21:55:37 - Initial Text Quality Analysis:
# 21:55:37 - {
#   "description": {
#     "min_length": 101,
#     "max_length": 93558,
#     "mean_length": 1039.0346120696172,
#     "median_length": 643.0,
#     "empty_count": 0,
#     "truncated_count": 166
#   },
#   "features": {
#     "min_length": 0,
#     "max_length": 5478,
#     "mean_length": 442.33393313474363,
#     "median_length": 335.0,
#     "empty_count": 7829
#   },
#   "issues": {
#     "html_entities": 14,
#     "excessive_whitespace": 2673,
#     "no_punctuation_features": 19736
#   }
# }

# %%
# Visualize text length distributions
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Description lengths
desc_lengths = df["description_text"].str.len_chars().to_list()
axes[0].hist(desc_lengths, bins=100, edgecolor="black", alpha=0.7, cumulative=True, density=True)
axes[0].axvline(np.median(desc_lengths), color="red", linestyle="--", label=f"Median: {np.median(desc_lengths):.0f}")
axes[0].set_xlabel("Character Count")
axes[0].set_ylabel("Number of Items")
axes[0].set_title("Description Text Length Distribution")
axes[0].legend()
axes[0].set_xlim(0, min(10000, max(desc_lengths)))

# Features lengths
feat_lengths = df["features_text"].str.len_chars().to_list()
feat_lengths_nonzero = [l for l in feat_lengths if l > 0]
axes[1].hist(feat_lengths_nonzero, bins=50, edgecolor="black", alpha=0.7, cumulative=True, density=True)
axes[1].axvline(
    np.median(feat_lengths_nonzero), color="red", linestyle="--", label=f"Median: {np.median(feat_lengths_nonzero):.0f}"
)
axes[1].set_xlabel("Character Count")
axes[1].set_ylabel("Number of Items")
axes[1].set_title("Features Text Length Distribution (non-empty)")
axes[1].legend()
axes[1].set_xlim(0, min(3000, max(feat_lengths_nonzero)))

plt.tight_layout()
plt.show()

# %% [markdown]
# # Initialize Gemini client

# %%
client = genai.Client()
logger.info("Gemini client initialized successfully")
# Out:
# 21:55:50 - Gemini client initialized successfully

# %%
try:
    test_response = client.models.generate_content(
        model=MODEL, contents="Say 'API connection successful' if you can read this."
    )
    logger.info(f"API Test: {test_response.text}")
except Exception as e:
    logger.error(f"Failed to initialize Gemini client: {e}")
    logger.error("Please ensure GEMINI_API_KEY environment variable is set")
    raise
# Out:
# 21:55:53 - API Test: API connection successful

# %% [markdown]
# ## 4. Define Cleaning Functions

# %%
PROMPT = """Gemini, you are a data cleaning expert who rewrites product descriptions to be clear, concise, and well-formatted.

Rewrite the following product description to be clear, concise, and well-formatted.

Instructions:
1. Fix grammar, spelling, and punctuation errors
2. Remove HTML entities (like &amp;, &lt;, &gt;)
3. Fix truncated sentences (ending with ...)
4. Remove excessive whitespace and formatting artifacts
5. Keep all important product information
6. Maintain a professional, informative tone
7. If the description seems cut off, complete it naturally
8. Convert bullet-point lists into coherent, readable text
9. Group related features together logically
10. Remove redundant information

IMPORTANT: Keep the cleaned description under 200 words.

For each item, return ONLY the cleaned description within <clean_description> tags.

Product description to clean:
<description>
{description}
<description>

Cleaned description:
<clean_description>
""".strip()

# %%
# CLEAN DESCRIPTION
def clean_description(prompt: str, description: str, model: str = MODEL) -> str:
    """
    Send a prompt and description to Gemini API for cleaning.

    Args:
        prompt: The cleaning instructions prompt
        description: The text description to clean
        model: The Gemini model to use (defaults to MODEL constant)

    Returns:
        Cleaned description text from Gemini
    """
    attempt = 0
    while attempt < MAX_RETRIES:
        try:
            # Format the full prompt with the description
            full_prompt = prompt.format(description=description)

            # Generate content using Gemini with suppressed output

            response = client.models.generate_content(model=model, contents=full_prompt)

            # Extract the cleaned text from response
            cleaned_text = f"{response.text.strip()}"

            # Extract content between tags if present
            if "<clean_description>" in cleaned_text and "</clean_description>" in cleaned_text:
                start = cleaned_text.find("<clean_description>") + len("<clean_description>")
                end = cleaned_text.find("</clean_description>")
                cleaned_text = cleaned_text[start:end].strip()
                return cleaned_text
            else:
                # If tags not found, increment attempt and retry
                attempt += 1
                if attempt < MAX_RETRIES:
                    logger.warning(f"Tags not found in response, retrying... (attempt {attempt}/{MAX_RETRIES})")
                    time.sleep(RETRY_DELAY)
                continue

        except Exception as e:
            attempt += 1
            if attempt < MAX_RETRIES:
                logger.warning(f"Error cleaning with Gemini: {e}, retrying... (attempt {attempt}/{MAX_RETRIES})")
                time.sleep(RETRY_DELAY)
            else:
                logger.error(f"Failed after {MAX_RETRIES} attempts: {e}")

    # Return original description if all attempts fail
    logger.warning(f"🚨 Returning 'NA' after {MAX_RETRIES} failed attempts")
    return "NA"


# Test the function with a sample description
test_description = df.head(1).select("description_text").item()
cleaned = clean_description(PROMPT, test_description)
logger.info(f"Original: {test_description}")
logger.info(f"Cleaned: {cleaned}")
# Out:
# 21:56:04 - Original: The Dash 8-300 Professional Add-On lets you pilot a real commuter special. Fly two versions of the popular Dash 8-300 in a total of 17 different liveries. The Dash 8-300 is one of the most popular short-haul aircraft available and this superbly modelled version from acclaimed aircraft developers PSS is modelled in two versions with a total of 17 different liveries. The package also includes scenery for three European airports, tutorials, tutorial flights and utilities together in one fantastic package.
# 21:56:04 - Cleaned: Experience the Dash 8-300 Professional Add-On, a meticulously crafted simulation of the popular commuter aircraft. This add-on features two distinct versions of the Dash 8-300, showcased in a total of 17 unique liveries. Developed by acclaimed aircraft specialists PSS, this simulation captures the essence of the short-haul favorite. The comprehensive package also includes scenery for three European airports, informative tutorials, guided tutorial flights, and essential utilities for an immersive flying experience.

# %% [markdown]
# ## 5. Parallel Processing with Checkpointing

# %%
# Setup checkpoint file
checkpoint_file = DATA_DIR / "output" / f"{CATEGORY}_descriptions_clean.csv"

# Load existing processed ASINs if checkpoint exists
processed_asins = set()
if checkpoint_file.exists():
    try:
        existing_df = pl.read_csv(checkpoint_file)
        existing_df = existing_df.filter(pl.col("clean_description") != "NA")
        processed_asins = set(existing_df["parent_asin"])
        logger.info(f"Found {len(processed_asins):,} already processed items in checkpoint file")
    except NoDataError as e:
        logger.error(f"CSV is empty: {e}")
        processed_asins = set()
else:
    # Create new CSV with headers
    with open(checkpoint_file, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["parent_asin", "clean_description"])
    logger.info(f"Created new checkpoint file: {checkpoint_file}")

# Filter to only unprocessed items
items_to_process = df.filter(~pl.col("parent_asin").is_in(processed_asins))
logger.info(f"Items to process: {len(items_to_process):,} out of {len(df):,} total items")

# Thread-safe CSV writing lock
csv_lock = threading.Lock()


def process_single_item(item_data):
    """Process a single item and save to CSV."""
    asin, description = item_data

    try:
        # Truncate description if too long
        if len(description) > MAX_DESCRIPTION_LENGTH:
            description = description[:MAX_DESCRIPTION_LENGTH]

        # Clean the description
        cleaned = clean_description(PROMPT, description)

        # Write immediately to CSV with lock
        with csv_lock:
            with open(checkpoint_file, "a", newline="", encoding="utf-8") as f:
                writer = csv.writer(f)
                writer.writerow([asin, cleaned])

        # Rate limiting
        time.sleep(RATE_LIMIT_DELAY)

        return asin, cleaned, True

    except Exception as e:
        logger.error(f"Failed to process {asin}: {e}")
        return asin, description, False


# Prepare items for processing
items = [(row["parent_asin"], row["description_text"]) for row in items_to_process.iter_rows(named=True)]

if len(items) > 0:
    logger.info(f"Starting parallel processing with {10} workers...")

    # Process with ThreadPoolExecutor
    successful = 0
    failed = 0

    with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
        # Submit all tasks
        futures = {executor.submit(process_single_item, item): item for item in items}

        # Process completions with progress bar
        with tqdm(total=len(futures), desc="Processing items") as pbar:
            for future in as_completed(futures):
                try:
                    asin, result, success = future.result()
                    if success:
                        successful += 1
                    else:
                        failed += 1
                    pbar.update(1)
                    pbar.set_postfix({"success": successful, "failed": failed})

                except Exception as e:
                    failed += 1
                    pbar.update(1)
                    pbar.set_postfix({"success": successful, "failed": failed})
                    logger.error(f"Future failed: {e}")

    logger.info(f"Processing complete! Successful: {successful:,}, Failed: {failed:,}")

else:
    logger.info("No items to process - all items already in checkpoint file!")
# Out:
# 21:57:00 - Created new checkpoint file: /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_descriptions_clean.csv
# 21:57:00 - Items to process: 66,133 out of 66,133 total items
# 21:57:01 - Starting parallel processing with 10 workers...
# Processing items:   0%|          | 0/66133 [00:00<?, ?it/s]
# 21:57:32 - Tags not found in response, retrying... (attempt 1/5)
# 21:57:42 - Tags not found in response, retrying... (attempt 1/5)
# 21:58:16 - Tags not found in response, retrying... (attempt 1/5)
# 21:58:19 - Tags not found in response, retrying... (attempt 1/5)
# 21:58:35 - Tags not found in response, retrying... (attempt 1/5)
# 21:58:55 - Tags not found in response, retrying... (attempt 1/5)
# 22:01:26 - Tags not found in response, retrying... (attempt 1/5)
# 22:01:54 - Tags not found in response, retrying... (attempt 1/5)
# 22:02:23 - Tags not found in response, retrying... (attempt 1/5)
# 22:03:12 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:03:15 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:26 - Tags not found in response, retrying... (attempt 1/5)
# 22:03:49 - Tags not found in response, retrying... (attempt 1/5)
# 22:03:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:57 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:57 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:58 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:59 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:03:59 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:04:02 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:04:03 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:04:04 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:04:49 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:04:51 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:04:52 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:04:57 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:05:03 - Tags not found in response, retrying... (attempt 1/5)
# 22:05:04 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:05:05 - Tags not found in response, retrying... (attempt 2/5)
# 22:05:08 - Tags not found in response, retrying... (attempt 3/5)
# 22:05:10 - Tags not found in response, retrying... (attempt 4/5)
# 22:05:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:05:12 - 🚨 Returning 'NA' after 5 failed attempts
# 22:05:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:05:57 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:05:58 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:16 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:16 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:20 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:21 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:21 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:23 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:37 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:52 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:52 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:54 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:54 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:06:58 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:06:58 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:06:59 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:07:06 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:07:25 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:08:39 - Tags not found in response, retrying... (attempt 1/5)
# 22:08:40 - Tags not found in response, retrying... (attempt 1/5)
# 22:09:00 - Tags not found in response, retrying... (attempt 1/5)
# 22:09:14 - Tags not found in response, retrying... (attempt 1/5)
# 22:09:16 - Tags not found in response, retrying... (attempt 2/5)
# 22:09:18 - Tags not found in response, retrying... (attempt 3/5)
# 22:09:21 - Tags not found in response, retrying... (attempt 4/5)
# 22:09:23 - 🚨 Returning 'NA' after 5 failed attempts
# 22:09:39 - Tags not found in response, retrying... (attempt 1/5)
# 22:09:42 - Tags not found in response, retrying... (attempt 2/5)
# 22:09:45 - Tags not found in response, retrying... (attempt 3/5)
# 22:09:48 - Tags not found in response, retrying... (attempt 4/5)
# 22:11:34 - Tags not found in response, retrying... (attempt 1/5)
# 22:11:37 - Tags not found in response, retrying... (attempt 1/5)
# 22:15:25 - Tags not found in response, retrying... (attempt 1/5)
# 22:16:50 - Tags not found in response, retrying... (attempt 1/5)
# 22:16:52 - Tags not found in response, retrying... (attempt 2/5)
# 22:17:32 - Tags not found in response, retrying... (attempt 1/5)
# 22:17:46 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:17:47 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:17:49 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:17:50 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:17:52 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:17:55 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:19:09 - Tags not found in response, retrying... (attempt 1/5)
# 22:19:11 - Tags not found in response, retrying... (attempt 2/5)
# 22:19:13 - Tags not found in response, retrying... (attempt 3/5)
# 22:20:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:20:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:20:39 - Tags not found in response, retrying... (attempt 1/5)
# 22:22:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:15 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:20 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:21 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:22:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 3/5)
# 22:22:43 - Tags not found in response, retrying... (attempt 1/5)
# 22:22:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:57 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:22:58 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:03 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:10 - Tags not found in response, retrying... (attempt 1/5)
# 22:23:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:23:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:15 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:16 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:16 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:23:26 - Tags not found in response, retrying... (attempt 1/5)
# 22:24:01 - Tags not found in response, retrying... (attempt 1/5)
# 22:24:23 - Tags not found in response, retrying... (attempt 1/5)
# 22:24:44 - Tags not found in response, retrying... (attempt 1/5)
# 22:24:46 - Tags not found in response, retrying... (attempt 2/5)
# 22:25:27 - Tags not found in response, retrying... (attempt 1/5)
# 22:25:30 - Tags not found in response, retrying... (attempt 2/5)
# 22:25:32 - Tags not found in response, retrying... (attempt 3/5)
# 22:26:22 - Tags not found in response, retrying... (attempt 1/5)
# 22:26:34 - Tags not found in response, retrying... (attempt 1/5)
# 22:26:41 - Tags not found in response, retrying... (attempt 1/5)
# 22:28:05 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:28:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:28:27 - Tags not found in response, retrying... (attempt 1/5)
# 22:28:30 - Tags not found in response, retrying... (attempt 2/5)
# 22:29:09 - Tags not found in response, retrying... (attempt 1/5)
# 22:29:12 - Tags not found in response, retrying... (attempt 2/5)
# 22:29:13 - Tags not found in response, retrying... (attempt 1/5)
# 22:30:43 - Tags not found in response, retrying... (attempt 1/5)
# 22:31:39 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:31:48 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:31:50 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:03 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:04 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:05 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:06 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:06 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:06 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:07 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:32:07 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:09 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:10 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:32:12 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:12 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 3/5)
# 22:32:12 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:13 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 4/5)
# 22:32:18 - Failed after 5 attempts: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 22:32:18 - 🚨 Returning 'NA' after 5 failed attempts
# 22:32:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:32:38 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:13 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:15 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:20 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:20 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:32 - Tags not found in response, retrying... (attempt 1/5)
# 22:33:34 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:33:34 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:36 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:33:36 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 3/5)
# 22:33:38 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:33:38 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 4/5)
# 22:33:41 - Failed after 5 attempts: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# 22:33:41 - 🚨 Returning 'NA' after 5 failed attempts
# 22:34:21 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:34:26 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:34:26 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:34:29 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:34:33 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:34:45 - Tags not found in response, retrying... (attempt 1/5)
# 22:34:52 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:34:58 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:35:27 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:35:29 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:35:29 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:35:34 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:35:47 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:35:54 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:36:11 - Tags not found in response, retrying... (attempt 1/5)
# 22:36:21 - Tags not found in response, retrying... (attempt 1/5)
# 22:36:33 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:00 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:04 - Tags not found in response, retrying... (attempt 1/5)
# 22:37:07 - Tags not found in response, retrying... (attempt 2/5)
# 22:37:08 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:21 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:37:32 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:39:32 - Tags not found in response, retrying... (attempt 1/5)
# 22:41:13 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:41:47 - Tags not found in response, retrying... (attempt 1/5)
# 22:41:51 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:42:12 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:07 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:08 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:10 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:12 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:13 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:16 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:17 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:43:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:44:04 - Tags not found in response, retrying... (attempt 1/5)
# 22:44:08 - Tags not found in response, retrying... (attempt 2/5)
# 22:44:11 - Tags not found in response, retrying... (attempt 1/5)
# 22:44:47 - Tags not found in response, retrying... (attempt 1/5)
# 22:45:29 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:45:58 - Tags not found in response, retrying... (attempt 1/5)
# 22:46:00 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:01 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:02 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:03 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:28 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:36 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:41 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:46:50 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:47:02 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:47:02 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:47:43 - Tags not found in response, retrying... (attempt 1/5)
# 22:48:27 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:48:31 - Tags not found in response, retrying... (attempt 1/5)
# 22:49:55 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:50:43 - Tags not found in response, retrying... (attempt 1/5)
# 22:50:52 - Tags not found in response, retrying... (attempt 1/5)
# 22:50:56 - Tags not found in response, retrying... (attempt 2/5)
# 22:51:16 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:51:37 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:51:52 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:51:54 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:51:58 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:00 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:02 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:02 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:02 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:04 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:52:04 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:49 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:51 - Tags not found in response, retrying... (attempt 1/5)
# 22:52:51 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:55 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:52:56 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:53:08 - Tags not found in response, retrying... (attempt 1/5)
# 22:53:10 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:53:14 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:53:17 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:05 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:05 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:05 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:15 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:17 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:22 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:23 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:25 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:30 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:31 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:33 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:34 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:36 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:37 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:54:38 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:54 - Tags not found in response, retrying... (attempt 1/5)
# 22:54:55 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:54:57 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:04 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:09 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:15 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:15 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:18 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 22:55:19 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:22 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:24 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:26 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:26 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:30 - Tags not found in response, retrying... (attempt 1/5)
# 22:55:32 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:40 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:40 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:41 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 22:55:41 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# ...
# 00:36:04 - Tags not found in response, retrying... (attempt 1/5)
# 00:37:40 - Tags not found in response, retrying... (attempt 1/5)
# 00:39:05 - Tags not found in response, retrying... (attempt 1/5)
# 00:40:30 - Tags not found in response, retrying... (attempt 1/5)
# 00:40:34 - Tags not found in response, retrying... (attempt 1/5)
# 00:42:53 - Tags not found in response, retrying... (attempt 1/5)
# 00:43:06 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:07 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:08 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:09 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:09 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 2/5)
# 00:43:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:11 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:26 - Error cleaning with Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}, retrying... (attempt 1/5)
# 00:43:30 - Tags not found in response, retrying... (attempt 1/5)
# 00:47:10 - Tags not found in response, retrying... (attempt 1/5)
# 00:47:13 - Tags not found in response, retrying... (attempt 2/5)
# 00:47:15 - Tags not found in response, retrying... (attempt 3/5)
# 00:47:18 - Tags not found in response, retrying... (attempt 4/5)
# 00:47:21 - 🚨 Returning 'NA' after 5 failed attempts
# 00:47:50 - Tags not found in response, retrying... (attempt 1/5)
# 00:48:45 - Tags not found in response, retrying... (attempt 1/5)
# 00:49:25 - Tags not found in response, retrying... (attempt 1/5)
# 00:50:14 - Tags not found in response, retrying... (attempt 1/5)
# 00:50:56 - Tags not found in response, retrying... (attempt 1/5)
# 00:51:10 - Tags not found in response, retrying... (attempt 1/5)
# 00:51:48 - Tags not found in response, retrying... (attempt 1/5)
# 08:10:18 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:10:18 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:10:36 - Tags not found in response, retrying... (attempt 1/5)
# 08:10:58 - Tags not found in response, retrying... (attempt 1/5)
# 08:13:19 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 1/5)
# 08:13:22 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 2/5)
# 08:13:24 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 3/5)
# 08:13:26 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 4/5)
# 08:13:29 - Failed after 5 attempts: 'NoneType' object has no attribute 'strip'
# 08:13:29 - 🚨 Returning 'NA' after 5 failed attempts
# 08:15:57 - Tags not found in response, retrying... (attempt 1/5)
# 08:16:05 - Tags not found in response, retrying... (attempt 1/5)
# 08:16:35 - Tags not found in response, retrying... (attempt 1/5)
# 08:17:03 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:03 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:03 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:03 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:17:04 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 1/5)
# 08:37:06 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:37:06 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:37:06 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 3/5)
# 08:37:07 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:37:07 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:37:07 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:37:07 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:37:07 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 3/5)
# 08:37:07 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:37:08 - Error cleaning with Gemini: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1002), retrying... (attempt 2/5)
# 08:39:16 - Tags not found in response, retrying... (attempt 1/5)
# 08:39:19 - Tags not found in response, retrying... (attempt 2/5)
# 08:40:13 - Tags not found in response, retrying... (attempt 1/5)
# 08:41:36 - Tags not found in response, retrying... (attempt 1/5)
# 08:46:10 - Tags not found in response, retrying... (attempt 1/5)
# 08:46:22 - Tags not found in response, retrying... (attempt 1/5)
# 08:46:24 - Tags not found in response, retrying... (attempt 2/5)
# 08:46:27 - Tags not found in response, retrying... (attempt 3/5)
# 08:46:29 - Tags not found in response, retrying... (attempt 4/5)
# 08:46:32 - 🚨 Returning 'NA' after 5 failed attempts
# 08:49:18 - Tags not found in response, retrying... (attempt 1/5)
# 08:51:28 - Tags not found in response, retrying... (attempt 1/5)
# 08:52:06 - Tags not found in response, retrying... (attempt 1/5)
# 08:52:22 - Tags not found in response, retrying... (attempt 1/5)
# 08:52:25 - Tags not found in response, retrying... (attempt 2/5)
# 08:53:30 - Tags not found in response, retrying... (attempt 1/5)
# 08:53:33 - Tags not found in response, retrying... (attempt 2/5)
# 08:53:37 - Tags not found in response, retrying... (attempt 1/5)
# 08:54:16 - Tags not found in response, retrying... (attempt 1/5)
# 08:55:34 - Tags not found in response, retrying... (attempt 1/5)
# 08:55:36 - Tags not found in response, retrying... (attempt 2/5)
# 08:55:37 - Tags not found in response, retrying... (attempt 1/5)
# 08:56:00 - Tags not found in response, retrying... (attempt 1/5)
# 08:56:02 - Tags not found in response, retrying... (attempt 1/5)
# 08:56:05 - Tags not found in response, retrying... (attempt 2/5)
# 08:56:08 - Tags not found in response, retrying... (attempt 3/5)
# 08:58:08 - Tags not found in response, retrying... (attempt 1/5)
# 08:59:34 - Tags not found in response, retrying... (attempt 1/5)
# 09:01:07 - Tags not found in response, retrying... (attempt 1/5)
# 09:03:35 - Tags not found in response, retrying... (attempt 1/5)
# 09:04:41 - Tags not found in response, retrying... (attempt 1/5)
# 09:04:59 - Tags not found in response, retrying... (attempt 1/5)
# 09:05:19 - Tags not found in response, retrying... (attempt 1/5)
# 09:05:28 - Tags not found in response, retrying... (attempt 1/5)
# 09:05:47 - Tags not found in response, retrying... (attempt 1/5)
# 09:05:55 - Tags not found in response, retrying... (attempt 1/5)
# 09:05:58 - Tags not found in response, retrying... (attempt 2/5)
# 09:06:01 - Tags not found in response, retrying... (attempt 3/5)
# 09:06:04 - Tags not found in response, retrying... (attempt 4/5)
# 09:06:07 - 🚨 Returning 'NA' after 5 failed attempts
# 09:09:15 - Tags not found in response, retrying... (attempt 1/5)
# 09:10:21 - Tags not found in response, retrying... (attempt 1/5)
# 09:10:36 - Tags not found in response, retrying... (attempt 1/5)
# 09:10:39 - Tags not found in response, retrying... (attempt 2/5)
# 09:10:42 - Tags not found in response, retrying... (attempt 3/5)
# 09:11:07 - Tags not found in response, retrying... (attempt 1/5)
# 09:12:01 - Tags not found in response, retrying... (attempt 1/5)
# 09:13:09 - Tags not found in response, retrying... (attempt 1/5)
# 09:13:47 - Tags not found in response, retrying... (attempt 1/5)
# 09:14:27 - Tags not found in response, retrying... (attempt 1/5)
# 09:14:35 - Tags not found in response, retrying... (attempt 1/5)
# 09:15:03 - Tags not found in response, retrying... (attempt 1/5)
# 09:15:06 - Tags not found in response, retrying... (attempt 2/5)
# 09:15:08 - Tags not found in response, retrying... (attempt 3/5)
# 09:15:10 - Tags not found in response, retrying... (attempt 4/5)
# 09:15:42 - Tags not found in response, retrying... (attempt 1/5)
# 09:16:00 - Tags not found in response, retrying... (attempt 1/5)
# 09:18:09 - Tags not found in response, retrying... (attempt 1/5)
# 09:18:12 - Tags not found in response, retrying... (attempt 2/5)
# 09:18:15 - Tags not found in response, retrying... (attempt 3/5)
# 09:18:17 - Tags not found in response, retrying... (attempt 4/5)
# 09:18:20 - 🚨 Returning 'NA' after 5 failed attempts
# 09:19:30 - Tags not found in response, retrying... (attempt 1/5)
# 09:24:26 - Tags not found in response, retrying... (attempt 1/5)
# 09:25:36 - Tags not found in response, retrying... (attempt 1/5)
# 09:26:42 - Tags not found in response, retrying... (attempt 1/5)
# 09:26:56 - Tags not found in response, retrying... (attempt 1/5)
# 09:27:18 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 1/5)
# 09:27:19 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 2/5)
# 09:27:21 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 3/5)
# 09:27:22 - Error cleaning with Gemini: 'NoneType' object has no attribute 'strip', retrying... (attempt 4/5)
# 09:27:24 - Failed after 5 attempts: 'NoneType' object has no attribute 'strip'
# 09:27:24 - 🚨 Returning 'NA' after 5 failed attempts
# 09:27:33 - Tags not found in response, retrying... (attempt 1/5)
# 09:29:05 - Tags not found in response, retrying... (attempt 1/5)
# 09:30:39 - Tags not found in response, retrying... (attempt 1/5)
# 09:31:50 - Tags not found in response, retrying... (attempt 1/5)
# 09:33:30 - Tags not found in response, retrying... (attempt 1/5)
# 09:33:32 - Tags not found in response, retrying... (attempt 2/5)
# 09:33:35 - Tags not found in response, retrying... (attempt 3/5)
# 09:33:37 - Tags not found in response, retrying... (attempt 4/5)
# 09:33:40 - 🚨 Returning 'NA' after 5 failed attempts
# 09:33:44 - Tags not found in response, retrying... (attempt 1/5)
# 09:33:46 - Tags not found in response, retrying... (attempt 2/5)
# 09:35:16 - Tags not found in response, retrying... (attempt 1/5)
# 09:35:18 - Tags not found in response, retrying... (attempt 2/5)
# 09:35:21 - Tags not found in response, retrying... (attempt 3/5)
# 09:35:23 - Tags not found in response, retrying... (attempt 4/5)
# 09:36:33 - Tags not found in response, retrying... (attempt 1/5)
# 09:38:22 - Tags not found in response, retrying... (attempt 1/5)
# 09:39:00 - Tags not found in response, retrying... (attempt 1/5)
# 09:39:13 - Tags not found in response, retrying... (attempt 1/5)
# 09:40:01 - Tags not found in response, retrying... (attempt 1/5)
# 09:41:04 - Tags not found in response, retrying... (attempt 1/5)
# 09:42:18 - Tags not found in response, retrying... (attempt 1/5)
# 09:43:31 - Tags not found in response, retrying... (attempt 1/5)
# 09:43:39 - Tags not found in response, retrying... (attempt 1/5)
# 09:44:37 - Tags not found in response, retrying... (attempt 1/5)
# 09:45:05 - Tags not found in response, retrying... (attempt 1/5)
# 09:45:08 - Tags not found in response, retrying... (attempt 2/5)
# 09:45:10 - Tags not found in response, retrying... (attempt 3/5)
# 09:45:13 - Tags not found in response, retrying... (attempt 4/5)
# 09:45:15 - 🚨 Returning 'NA' after 5 failed attempts
# 09:45:49 - Tags not found in response, retrying... (attempt 1/5)
# 09:47:16 - Tags not found in response, retrying... (attempt 1/5)
# 09:47:19 - Tags not found in response, retrying... (attempt 2/5)
# 09:47:25 - Tags not found in response, retrying... (attempt 1/5)
# 09:47:32 - Tags not found in response, retrying... (attempt 1/5)
# 09:51:20 - Tags not found in response, retrying... (attempt 1/5)
# 09:52:05 - Tags not found in response, retrying... (attempt 1/5)
# 09:52:27 - Tags not found in response, retrying... (attempt 1/5)
# 09:54:19 - Tags not found in response, retrying... (attempt 1/5)
# 09:54:27 - Tags not found in response, retrying... (attempt 1/5)
# 09:54:28 - Tags not found in response, retrying... (attempt 1/5)
# 09:54:29 - Tags not found in response, retrying... (attempt 2/5)
# 09:55:47 - Tags not found in response, retrying... (attempt 1/5)
# 09:55:50 - Tags not found in response, retrying... (attempt 2/5)
# 09:55:52 - Tags not found in response, retrying... (attempt 3/5)
# 09:55:54 - Tags not found in response, retrying... (attempt 4/5)
# 09:56:50 - Tags not found in response, retrying... (attempt 1/5)
# 09:56:58 - Tags not found in response, retrying... (attempt 1/5)
# 09:57:20 - Tags not found in response, retrying... (attempt 1/5)
# 09:57:23 - Tags not found in response, retrying... (attempt 1/5)
# 09:58:20 - Tags not found in response, retrying... (attempt 1/5)
# 09:58:56 - Tags not found in response, retrying... (attempt 1/5)
# 09:59:06 - Tags not found in response, retrying... (attempt 1/5)
# 09:59:30 - Processing complete! Successful: 66,133, Failed: 0

# %% [markdown]
# ## 6. Verify and Load Results

# %%
# Load and verify the cleaned descriptions
if checkpoint_file.exists():
    cleaned_df = pl.read_csv(checkpoint_file)
    logger.info(f"Loaded {len(cleaned_df):,} cleaned descriptions from {checkpoint_file}")

    # Display sample of cleaned data
    logger.info("Sample of cleaned descriptions:")
    display(cleaned_df.head(3))

else:
    logger.warning("No checkpoint file found. Run the processing cell first.")
# Out:
# 10:00:41 - Loaded 66,133 cleaned descriptions from /home/zihao/llm/semantic-ids-llm/data/output/Video_Games_descriptions_clean.csv
# 10:00:41 - Sample of cleaned descriptions:
# shape: (3, 2)
# ┌─────────────┬─────────────────────────────────┐
# │ parent_asin ┆ clean_description               │
# │ ---         ┆ ---                             │
# │ str         ┆ str                             │
# ╞═════════════╪═════════════════════════════════╡
# │ B00006969T  ┆ The Konami Collector's Series:… │
# │ B00Z9TLVK0  ┆ Experience the unparalleled au… │
# │ B000FH0MHO  ┆ Experience the thrill of pilot… │
# └─────────────┴─────────────────────────────────┘
